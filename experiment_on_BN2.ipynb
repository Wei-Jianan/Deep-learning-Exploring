# %%
import sys
sys.path.insert(0, '..')
import gluonbook as gb
from mxnet import nd, gluon, init, autograd
from mxnet.gluon import nn

def batch_norm(X, gamma, beta, moving_mean, moving_var,
               eps, momentum):
    # 通过 autograd 来获取是不是在训练环境下。
    if not autograd.is_training():
        # 如果是在预测模式下，直接使用传入的移动平滑均值和方差。
        X_hat = (X - moving_mean) / nd.sqrt(moving_var + eps)
    else:
        assert len(X.shape) in (2, 4)
        # 接在全连接层后情况，计算特征维上的均值和方差。
        if len(X.shape) == 2:
            mean = X.mean(axis=0)
            var = ((X - mean)**2).mean(axis=0)
        # 接在二维卷积层后的情况，计算通道维上（axis=1）的均值和方差。这里我们需要保持 X
        # 的形状以便后面可以正常的做广播运算。
        else:
            mean = X.mean(axis=(0,2,3), keepdims=True)
            var = ((X - mean)**2).mean(axis=(0,2,3), keepdims=True)
        # 训练模式下用当前的均值和方差做归一化。
        X_hat = (X - mean) / nd.sqrt(var + eps)
        # 更新移动平滑均值和方差。
        moving_mean = momentum * moving_mean + (1.0 - momentum) * mean
        moving_var = momentum * moving_var + (1.0 - momentum) * var
    # 拉升和偏移
    Y = gamma * X_hat + beta
    return (Y, moving_mean, moving_var)

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero())
        self.gamma = self.params.get('gamma', shape=shape, init=init.One())
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
    BatchNorm(6, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
    BatchNorm(16, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
    BatchNorm(120, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(84),
    BatchNorm(84, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(10)
)

lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.6536, train acc 0.768, test acc 0.826, time 3.7 sec
# epoch 2, loss 0.3949, train acc 0.857, test acc 0.821, time 3.7 sec
# epoch 3, loss 0.3456, train acc 0.875, test acc 0.873, time 3.7 sec
# epoch 4, loss 0.3215, train acc 0.882, test acc 0.856, time 3.7 sec
# epoch 5, loss 0.3001, train acc 0.891, test acc 0.868, time 3.7 sec
# epoch 6, loss 0.2862, train acc 0.896, test acc 0.880, time 3.7 sec
# epoch 7, loss 0.2724, train acc 0.902, test acc 0.884, time 3.7 sec
# epoch 8, loss 0.2624, train acc 0.904, test acc 0.884, time 3.7 sec
# epoch 9, loss 0.2516, train acc 0.908, test acc 0.897, time 3.7 sec
# epoch 10, loss 0.2437, train acc 0.911, test acc 0.862, time 3.7 sec
# epoch 11, loss 0.2378, train acc 0.912, test acc 0.884, time 3.7 sec
# epoch 12, loss 0.2307, train acc 0.915, test acc 0.815, time 3.7 sec
# epoch 13, loss 0.2245, train acc 0.917, test acc 0.889, time 3.7 sec
# epoch 14, loss 0.2175, train acc 0.920, test acc 0.903, time 3.7 sec
# epoch 15, loss 0.2113, train acc 0.922, test acc 0.894, time 3.6 sec
# epoch 16, loss 0.2110, train acc 0.923, test acc 0.905, time 3.7 sec
# epoch 17, loss 0.2008, train acc 0.926, test acc 0.903, time 3.7 sec
# epoch 18, loss 0.1976, train acc 0.928, test acc 0.898, time 3.7 sec
# epoch 19, loss 0.1940, train acc 0.929, test acc 0.878, time 3.7 sec
# epoch 20, loss 0.1854, train acc 0.932, test acc 0.898, time 3.7 sec
# epoch 21, loss 0.1814, train acc 0.934, test acc 0.906, time 3.7 sec
# epoch 22, loss 0.1775, train acc 0.935, test acc 0.860, time 3.6 sec
# epoch 23, loss 0.1734, train acc 0.936, test acc 0.889, time 3.7 sec
# epoch 24, loss 0.1698, train acc 0.937, test acc 0.889, time 3.7 sec
# epoch 25, loss 0.1625, train acc 0.940, test acc 0.900, time 3.8 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2fdb44d6536c> in <module>()
#      25 loss = gluon.loss.SoftmaxCrossEntropyLoss()
#      26 train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
# ---> 27 gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
#
# ~\Downloads\gluon-tutorials-zh\gluonbook\utils.py in train(train_iter, test_iter, net, loss, trainer, ctx, num_epochs, print_batches)
#     187                 l.backward()
#     188             train_acc_sum += sum([(y_hat.argmax(axis=1) == y).sum().asscalar()
# --> 189                                  for y_hat, y in zip(y_hats, ys)])
#     190             train_l_sum += sum([l.sum().asscalar() for l in ls])
#     191             trainer.step(batch_size)
#
# ~\Downloads\gluon-tutorials-zh\gluonbook\utils.py in <listcomp>(.0)
#     187                 l.backward()
#     188             train_acc_sum += sum([(y_hat.argmax(axis=1) == y).sum().asscalar()
# --> 189                                  for y_hat, y in zip(y_hats, ys)])
#     190             train_l_sum += sum([l.sum().asscalar() for l in ls])
#     191             trainer.step(batch_size)
#
# ~\anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asscalar(self)
#    1892         if self.shape != (1,):
#    1893             raise ValueError("The current array is not a scalar")
# -> 1894         return self.asnumpy()[0]
#    1895
#    1896     def astype(self, dtype, copy=True):
#
# ~\anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asnumpy(self)
#    1874             self.handle,
#    1875             data.ctypes.data_as(ctypes.c_void_p),
# -> 1876             ctypes.c_size_t(data.size)))
#    1877         return data
#    1878
#
# KeyboardInterrupt:

# %%
lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.6647, train acc 0.761, test acc 0.715, time 6.4 sec
# epoch 2, loss 0.4011, train acc 0.855, test acc 0.826, time 3.7 sec
# epoch 3, loss 0.3511, train acc 0.871, test acc 0.860, time 3.7 sec
# epoch 4, loss 0.3221, train acc 0.882, test acc 0.841, time 3.7 sec
# epoch 5, loss 0.2999, train acc 0.891, test acc 0.869, time 3.7 sec
# epoch 6, loss 0.2872, train acc 0.894, test acc 0.773, time 3.7 sec
# epoch 7, loss 0.2748, train acc 0.899, test acc 0.859, time 3.7 sec
# epoch 8, loss 0.2634, train acc 0.903, test acc 0.868, time 3.6 sec
# epoch 9, loss 0.2555, train acc 0.907, test acc 0.878, time 3.6 sec
# epoch 10, loss 0.2466, train acc 0.908, test acc 0.864, time 3.7 sec
# epoch 11, loss 0.2429, train acc 0.910, test acc 0.889, time 3.7 sec
# epoch 12, loss 0.2331, train acc 0.915, test acc 0.884, time 3.7 sec
# epoch 13, loss 0.2277, train acc 0.916, test acc 0.883, time 3.7 sec
# epoch 14, loss 0.2220, train acc 0.918, test acc 0.897, time 3.7 sec
# epoch 15, loss 0.2166, train acc 0.920, test acc 0.888, time 3.7 sec
# epoch 16, loss 0.2092, train acc 0.923, test acc 0.839, time 3.7 sec
# epoch 17, loss 0.2049, train acc 0.925, test acc 0.886, time 3.6 sec
# epoch 18, loss 0.1994, train acc 0.926, test acc 0.905, time 3.7 sec
# epoch 19, loss 0.1949, train acc 0.927, test acc 0.894, time 3.7 sec
# epoch 20, loss 0.1892, train acc 0.930, test acc 0.896, time 3.7 sec
# epoch 21, loss 0.1852, train acc 0.931, test acc 0.901, time 3.7 sec
# epoch 22, loss 0.1787, train acc 0.934, test acc 0.877, time 3.7 sec
# epoch 23, loss 0.1740, train acc 0.936, test acc 0.891, time 3.7 sec
# epoch 24, loss 0.1724, train acc 0.936, test acc 0.883, time 3.7 sec
# epoch 25, loss 0.1673, train acc 0.938, test acc 0.889, time 3.7 sec
# epoch 26, loss 0.1625, train acc 0.940, test acc 0.903, time 3.6 sec
# epoch 27, loss 0.1572, train acc 0.941, test acc 0.898, time 3.7 sec
# epoch 28, loss 0.1542, train acc 0.944, test acc 0.873, time 3.7 sec
# epoch 29, loss 0.1460, train acc 0.946, test acc 0.896, time 3.7 sec
# epoch 30, loss 0.1440, train acc 0.947, test acc 0.896, time 3.6 sec
# epoch 31, loss 0.1388, train acc 0.950, test acc 0.886, time 3.7 sec
# epoch 32, loss 0.1360, train acc 0.950, test acc 0.873, time 3.7 sec
# epoch 33, loss 0.1307, train acc 0.953, test acc 0.894, time 3.7 sec
# epoch 34, loss 0.1282, train acc 0.952, test acc 0.881, time 3.7 sec
# epoch 35, loss 0.1236, train acc 0.955, test acc 0.885, time 3.7 sec
# epoch 36, loss 0.1194, train acc 0.956, test acc 0.903, time 3.7 sec
# epoch 37, loss 0.1132, train acc 0.959, test acc 0.887, time 3.7 sec
# epoch 38, loss 0.1082, train acc 0.961, test acc 0.868, time 3.7 sec
# epoch 39, loss 0.1059, train acc 0.962, test acc 0.890, time 3.7 sec
# epoch 40, loss 0.1012, train acc 0.964, test acc 0.895, time 3.6 sec
# epoch 41, loss 0.0973, train acc 0.965, test acc 0.895, time 3.7 sec
# epoch 42, loss 0.0954, train acc 0.965, test acc 0.894, time 3.7 sec
# epoch 43, loss 0.0920, train acc 0.967, test acc 0.888, time 3.7 sec
# epoch 44, loss 0.0862, train acc 0.970, test acc 0.890, time 3.8 sec
# epoch 45, loss 0.0821, train acc 0.971, test acc 0.873, time 3.7 sec
# epoch 46, loss 0.0815, train acc 0.971, test acc 0.891, time 3.8 sec
# epoch 47, loss 0.0759, train acc 0.974, test acc 0.890, time 3.7 sec
# epoch 48, loss 0.0697, train acc 0.976, test acc 0.893, time 3.7 sec
# epoch 49, loss 0.0699, train acc 0.976, test acc 0.894, time 3.7 sec
# epoch 50, loss 0.0656, train acc 0.978, test acc 0.889, time 3.6 sec
# epoch 51, loss 0.0647, train acc 0.977, test acc 0.887, time 3.8 sec
# epoch 52, loss 0.0600, train acc 0.979, test acc 0.894, time 3.7 sec
# epoch 53, loss 0.0565, train acc 0.981, test acc 0.874, time 3.7 sec
# epoch 54, loss 0.0515, train acc 0.983, test acc 0.889, time 3.8 sec
# epoch 55, loss 0.0514, train acc 0.983, test acc 0.864, time 3.7 sec
# epoch 56, loss 0.0478, train acc 0.985, test acc 0.892, time 3.7 sec
# epoch 57, loss 0.0441, train acc 0.986, test acc 0.897, time 3.7 sec
# epoch 58, loss 0.0391, train acc 0.988, test acc 0.892, time 3.8 sec
# epoch 59, loss 0.0407, train acc 0.987, test acc 0.896, time 3.6 sec
# epoch 60, loss 0.0348, train acc 0.990, test acc 0.868, time 3.8 sec
# epoch 61, loss 0.0319, train acc 0.991, test acc 0.895, time 3.7 sec
# epoch 62, loss 0.0339, train acc 0.990, test acc 0.894, time 3.7 sec
# epoch 63, loss 0.0300, train acc 0.991, test acc 0.896, time 3.8 sec
# epoch 64, loss 0.0299, train acc 0.991, test acc 0.899, time 3.7 sec
# epoch 65, loss 0.0278, train acc 0.992, test acc 0.893, time 3.7 sec
# epoch 66, loss 0.0246, train acc 0.994, test acc 0.892, time 3.7 sec
# epoch 67, loss 0.0217, train acc 0.995, test acc 0.899, time 3.7 sec
# epoch 68, loss 0.0219, train acc 0.995, test acc 0.881, time 3.8 sec
# epoch 69, loss 0.0195, train acc 0.995, test acc 0.896, time 3.6 sec
# epoch 70, loss 0.0186, train acc 0.996, test acc 0.885, time 3.7 sec
# epoch 71, loss 0.0151, train acc 0.997, test acc 0.894, time 3.8 sec
# epoch 72, loss 0.0162, train acc 0.997, test acc 0.895, time 3.7 sec
# epoch 73, loss 0.0198, train acc 0.995, test acc 0.863, time 3.6 sec
# epoch 74, loss 0.0184, train acc 0.995, test acc 0.897, time 3.8 sec
# epoch 75, loss 0.0146, train acc 0.997, test acc 0.892, time 3.6 sec
# epoch 76, loss 0.0121, train acc 0.998, test acc 0.901, time 3.8 sec
# epoch 77, loss 0.0095, train acc 0.999, test acc 0.898, time 3.8 sec
# epoch 78, loss 0.0083, train acc 0.999, test acc 0.898, time 3.8 sec
# epoch 79, loss 0.0075, train acc 0.999, test acc 0.901, time 3.6 sec
# epoch 80, loss 0.0069, train acc 0.999, test acc 0.899, time 3.7 sec
# epoch 81, loss 0.0069, train acc 0.999, test acc 0.900, time 3.7 sec
# epoch 82, loss 0.0057, train acc 1.000, test acc 0.901, time 3.7 sec
# epoch 83, loss 0.0050, train acc 1.000, test acc 0.901, time 3.7 sec
# epoch 84, loss 0.0266, train acc 0.993, test acc 0.878, time 3.7 sec
# epoch 85, loss 0.0234, train acc 0.993, test acc 0.888, time 3.7 sec
# epoch 86, loss 0.0129, train acc 0.997, test acc 0.894, time 3.8 sec
# epoch 87, loss 0.0083, train acc 0.999, test acc 0.898, time 3.7 sec
# epoch 88, loss 0.0069, train acc 0.999, test acc 0.873, time 3.8 sec
# epoch 89, loss 0.0048, train acc 1.000, test acc 0.899, time 3.7 sec
# epoch 90, loss 0.0054, train acc 1.000, test acc 0.898, time 3.7 sec
# epoch 91, loss 0.0043, train acc 1.000, test acc 0.901, time 3.7 sec
# epoch 92, loss 0.0037, train acc 1.000, test acc 0.900, time 3.8 sec
# epoch 93, loss 0.0031, train acc 1.000, test acc 0.901, time 3.7 sec
# epoch 94, loss 0.0030, train acc 1.000, test acc 0.900, time 3.7 sec
# epoch 95, loss 0.0026, train acc 1.000, test acc 0.901, time 3.8 sec
# epoch 96, loss 0.0029, train acc 1.000, test acc 0.902, time 3.8 sec
# epoch 97, loss 0.0027, train acc 1.000, test acc 0.899, time 3.7 sec
# epoch 98, loss 0.0025, train acc 1.000, test acc 0.900, time 3.7 sec
# epoch 99, loss 0.0023, train acc 1.000, test acc 0.901, time 3.7 sec
# epoch 100, loss 0.0022, train acc 1.000, test acc 0.900, time 3.7 sec

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),

    nn.Activation('sigmoid'),

    nn.MaxPool2D(pool_size=2, strides=2),
            BatchNorm(6, num_dims=4),
    nn.Conv2D(16, kernel_size=5),
   
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
     BatchNorm(16, num_dims=4),
    nn.Dense(120),
    
    nn.Activation('sigmoid'),
    BatchNorm(120, num_dims=2),
    nn.Dense(84),
   
    nn.Activation('sigmoid'),
     BatchNorm(84, num_dims=2),
    nn.Dense(10)
)
lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.7248, train acc 0.748, test acc 0.826, time 3.5 sec
# epoch 2, loss 0.4027, train acc 0.850, test acc 0.852, time 3.5 sec
# epoch 3, loss 0.3482, train acc 0.870, test acc 0.874, time 3.5 sec
# epoch 4, loss 0.3246, train acc 0.879, test acc 0.857, time 3.4 sec
# epoch 5, loss 0.3027, train acc 0.888, test acc 0.884, time 3.4 sec
# epoch 6, loss 0.2880, train acc 0.891, test acc 0.882, time 3.5 sec
# epoch 7, loss 0.2724, train acc 0.899, test acc 0.880, time 3.5 sec
# epoch 8, loss 0.2636, train acc 0.901, test acc 0.891, time 3.5 sec
# epoch 9, loss 0.2546, train acc 0.905, test acc 0.865, time 3.5 sec
# epoch 10, loss 0.2457, train acc 0.908, test acc 0.901, time 3.5 sec
# epoch 11, loss 0.2379, train acc 0.911, test acc 0.890, time 3.6 sec
# epoch 12, loss 0.2314, train acc 0.913, test acc 0.879, time 3.6 sec
# epoch 13, loss 0.2249, train acc 0.916, test acc 0.866, time 3.5 sec
# epoch 14, loss 0.2188, train acc 0.917, test acc 0.846, time 3.6 sec
# epoch 15, loss 0.2132, train acc 0.918, test acc 0.902, time 3.5 sec
# epoch 16, loss 0.2078, train acc 0.921, test acc 0.899, time 3.5 sec
# epoch 17, loss 0.2046, train acc 0.922, test acc 0.886, time 3.5 sec
# epoch 18, loss 0.1961, train acc 0.925, test acc 0.902, time 3.5 sec
# epoch 19, loss 0.1966, train acc 0.925, test acc 0.901, time 3.5 sec
# epoch 20, loss 0.1899, train acc 0.927, test acc 0.902, time 3.5 sec
# epoch 21, loss 0.1856, train acc 0.929, test acc 0.898, time 3.5 sec
# epoch 22, loss 0.1817, train acc 0.931, test acc 0.886, time 3.5 sec
# epoch 23, loss 0.1776, train acc 0.932, test acc 0.884, time 3.5 sec
# epoch 24, loss 0.1757, train acc 0.933, test acc 0.891, time 3.5 sec
# epoch 25, loss 0.1713, train acc 0.935, test acc 0.894, time 3.5 sec
# epoch 26, loss 0.1686, train acc 0.936, test acc 0.902, time 3.5 sec
# epoch 27, loss 0.1645, train acc 0.936, test acc 0.896, time 3.5 sec
# epoch 28, loss 0.1619, train acc 0.939, test acc 0.895, time 3.5 sec
# epoch 29, loss 0.1613, train acc 0.938, test acc 0.886, time 3.5 sec
# epoch 30, loss 0.1581, train acc 0.940, test acc 0.880, time 3.5 sec
# epoch 31, loss 0.1543, train acc 0.941, test acc 0.899, time 3.5 sec
# epoch 32, loss 0.1509, train acc 0.943, test acc 0.889, time 3.5 sec
# epoch 33, loss 0.1475, train acc 0.943, test acc 0.895, time 3.5 sec
# epoch 34, loss 0.1471, train acc 0.945, test acc 0.889, time 3.5 sec
# epoch 35, loss 0.1458, train acc 0.945, test acc 0.892, time 3.5 sec
# epoch 36, loss 0.1430, train acc 0.945, test acc 0.881, time 3.5 sec
# epoch 37, loss 0.1441, train acc 0.946, test acc 0.898, time 3.5 sec
# epoch 38, loss 0.1377, train acc 0.947, test acc 0.890, time 3.6 sec
# epoch 39, loss 0.1359, train acc 0.949, test acc 0.896, time 3.7 sec
# epoch 40, loss 0.1323, train acc 0.950, test acc 0.892, time 3.6 sec
# epoch 41, loss 0.1340, train acc 0.950, test acc 0.888, time 3.6 sec
# epoch 42, loss 0.1333, train acc 0.949, test acc 0.886, time 3.5 sec
# epoch 43, loss 0.1297, train acc 0.950, test acc 0.874, time 3.6 sec
# epoch 44, loss 0.1235, train acc 0.953, test acc 0.893, time 3.6 sec
# epoch 45, loss 0.1292, train acc 0.951, test acc 0.891, time 3.6 sec
# epoch 46, loss 0.1205, train acc 0.954, test acc 0.866, time 3.5 sec
# epoch 47, loss 0.1198, train acc 0.954, test acc 0.895, time 3.5 sec
# epoch 48, loss 0.1234, train acc 0.953, test acc 0.883, time 3.5 sec
# epoch 49, loss 0.1182, train acc 0.955, test acc 0.888, time 3.6 sec
# epoch 50, loss 0.1174, train acc 0.956, test acc 0.878, time 3.5 sec
# epoch 51, loss 0.1148, train acc 0.956, test acc 0.876, time 3.6 sec
# epoch 52, loss 0.1139, train acc 0.957, test acc 0.900, time 3.5 sec
# epoch 53, loss 0.1128, train acc 0.958, test acc 0.895, time 3.5 sec
# epoch 54, loss 0.1080, train acc 0.959, test acc 0.896, time 3.6 sec
# epoch 55, loss 0.1104, train acc 0.958, test acc 0.897, time 3.6 sec
# epoch 56, loss 0.1129, train acc 0.958, test acc 0.876, time 3.6 sec
# epoch 57, loss 0.1015, train acc 0.962, test acc 0.894, time 3.6 sec
# epoch 58, loss 0.1064, train acc 0.960, test acc 0.884, time 3.6 sec
# epoch 59, loss 0.1049, train acc 0.960, test acc 0.895, time 3.6 sec
# epoch 60, loss 0.1053, train acc 0.960, test acc 0.892, time 3.7 sec
# epoch 61, loss 0.1058, train acc 0.960, test acc 0.889, time 3.6 sec
# epoch 62, loss 0.0994, train acc 0.963, test acc 0.884, time 3.6 sec
# epoch 63, loss 0.1094, train acc 0.958, test acc 0.886, time 3.6 sec
# epoch 64, loss 0.1010, train acc 0.961, test acc 0.890, time 3.6 sec
# epoch 65, loss 0.0942, train acc 0.965, test acc 0.887, time 3.6 sec
# epoch 66, loss 0.0990, train acc 0.963, test acc 0.856, time 3.5 sec
# epoch 67, loss 0.0964, train acc 0.963, test acc 0.890, time 3.6 sec
# epoch 68, loss 0.1005, train acc 0.963, test acc 0.897, time 3.5 sec
# epoch 69, loss 0.0929, train acc 0.966, test acc 0.889, time 3.6 sec
# epoch 70, loss 0.0937, train acc 0.965, test acc 0.888, time 3.5 sec
# epoch 71, loss 0.0888, train acc 0.967, test acc 0.888, time 3.5 sec
# epoch 72, loss 0.0930, train acc 0.965, test acc 0.891, time 3.5 sec
# epoch 73, loss 0.0861, train acc 0.968, test acc 0.896, time 3.5 sec
# epoch 74, loss 0.0950, train acc 0.963, test acc 0.894, time 3.5 sec
# epoch 75, loss 0.0826, train acc 0.969, test acc 0.889, time 3.5 sec
# epoch 76, loss 0.0907, train acc 0.966, test acc 0.879, time 3.5 sec
# epoch 77, loss 0.0886, train acc 0.966, test acc 0.891, time 3.5 sec
# epoch 78, loss 0.0852, train acc 0.968, test acc 0.864, time 3.5 sec
# epoch 79, loss 0.0904, train acc 0.966, test acc 0.892, time 3.5 sec
# epoch 80, loss 0.0805, train acc 0.970, test acc 0.892, time 3.5 sec
# epoch 81, loss 0.0919, train acc 0.965, test acc 0.889, time 3.5 sec
# epoch 82, loss 0.0792, train acc 0.971, test acc 0.880, time 3.5 sec
# epoch 83, loss 0.0870, train acc 0.967, test acc 0.889, time 3.5 sec
# epoch 84, loss 0.0839, train acc 0.968, test acc 0.889, time 3.5 sec
# epoch 85, loss 0.0765, train acc 0.971, test acc 0.886, time 3.5 sec
# epoch 86, loss 0.0846, train acc 0.969, test acc 0.880, time 3.5 sec
# epoch 87, loss 0.0808, train acc 0.970, test acc 0.890, time 3.5 sec
# epoch 88, loss 0.0845, train acc 0.968, test acc 0.878, time 3.5 sec
# epoch 89, loss 0.0809, train acc 0.969, test acc 0.892, time 3.5 sec
# epoch 90, loss 0.0738, train acc 0.972, test acc 0.894, time 3.5 sec
# epoch 91, loss 0.0699, train acc 0.973, test acc 0.892, time 3.6 sec
# epoch 92, loss 0.0843, train acc 0.968, test acc 0.889, time 3.6 sec
# epoch 93, loss 0.0727, train acc 0.973, test acc 0.887, time 3.5 sec
# epoch 94, loss 0.0831, train acc 0.969, test acc 0.885, time 3.5 sec
# epoch 95, loss 0.0686, train acc 0.975, test acc 0.892, time 3.6 sec
# epoch 96, loss 0.0783, train acc 0.970, test acc 0.891, time 3.5 sec
# epoch 97, loss 0.0699, train acc 0.974, test acc 0.875, time 3.5 sec
# epoch 98, loss 0.0812, train acc 0.970, test acc 0.893, time 3.5 sec
# epoch 99, loss 0.0694, train acc 0.975, test acc 0.894, time 3.6 sec
# epoch 100, loss 0.0882, train acc 0.967, test acc 0.887, time 3.6 sec

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),

    nn.Activation('relu'),
 
    nn.MaxPool2D(pool_size=2, strides=2),
           BatchNorm(6, num_dims=4),
    nn.Conv2D(16, kernel_size=5),
   
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
     BatchNorm(16, num_dims=4),
    nn.Dense(120),
    
    nn.Activation('relu'),
    BatchNorm(120, num_dims=2),
    nn.Dense(84),
   
    nn.Activation('relu'),
     BatchNorm(84, num_dims=2),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.5337, train acc 0.809, test acc 0.853, time 3.4 sec
# epoch 2, loss 0.3677, train acc 0.867, test acc 0.864, time 3.4 sec
# epoch 3, loss 0.3264, train acc 0.882, test acc 0.876, time 3.4 sec
# epoch 4, loss 0.3025, train acc 0.889, test acc 0.888, time 3.4 sec
# epoch 5, loss 0.2837, train acc 0.896, test acc 0.854, time 3.4 sec
# epoch 6, loss 0.2693, train acc 0.901, test acc 0.891, time 3.5 sec
# epoch 7, loss 0.2585, train acc 0.905, test acc 0.901, time 3.4 sec
# epoch 8, loss 0.2475, train acc 0.909, test acc 0.898, time 3.4 sec
# epoch 9, loss 0.2383, train acc 0.912, test acc 0.893, time 3.4 sec
# epoch 10, loss 0.2288, train acc 0.916, test acc 0.903, time 3.4 sec
# epoch 11, loss 0.2219, train acc 0.918, test acc 0.898, time 3.4 sec
# epoch 12, loss 0.2122, train acc 0.922, test acc 0.899, time 3.4 sec
# epoch 13, loss 0.2085, train acc 0.922, test acc 0.894, time 3.5 sec
# epoch 14, loss 0.2010, train acc 0.926, test acc 0.899, time 3.4 sec
# epoch 15, loss 0.1936, train acc 0.929, test acc 0.900, time 3.4 sec
# epoch 16, loss 0.1887, train acc 0.929, test acc 0.898, time 3.3 sec
# epoch 17, loss 0.1823, train acc 0.933, test acc 0.906, time 3.4 sec
# epoch 18, loss 0.1781, train acc 0.934, test acc 0.902, time 3.4 sec
# epoch 19, loss 0.1736, train acc 0.935, test acc 0.899, time 3.4 sec
# epoch 20, loss 0.1670, train acc 0.938, test acc 0.907, time 3.4 sec
# epoch 21, loss 0.1636, train acc 0.940, test acc 0.899, time 3.4 sec
# epoch 22, loss 0.1591, train acc 0.941, test acc 0.900, time 3.4 sec
# epoch 23, loss 0.1534, train acc 0.943, test acc 0.902, time 3.4 sec
# epoch 24, loss 0.1489, train acc 0.945, test acc 0.905, time 3.4 sec
# epoch 25, loss 0.1433, train acc 0.948, test acc 0.903, time 3.4 sec
# epoch 26, loss 0.1412, train acc 0.948, test acc 0.907, time 3.4 sec
# epoch 27, loss 0.1375, train acc 0.949, test acc 0.877, time 3.4 sec
# epoch 28, loss 0.1320, train acc 0.952, test acc 0.904, time 3.3 sec
# epoch 29, loss 0.1285, train acc 0.953, test acc 0.895, time 3.4 sec
# epoch 30, loss 0.1252, train acc 0.954, test acc 0.902, time 3.4 sec
# epoch 31, loss 0.1199, train acc 0.956, test acc 0.897, time 3.4 sec
# epoch 32, loss 0.1180, train acc 0.957, test acc 0.902, time 3.4 sec
# epoch 33, loss 0.1140, train acc 0.958, test acc 0.903, time 3.4 sec
# epoch 34, loss 0.1128, train acc 0.959, test acc 0.901, time 3.4 sec
# epoch 35, loss 0.1068, train acc 0.961, test acc 0.902, time 3.4 sec
# epoch 36, loss 0.1029, train acc 0.963, test acc 0.897, time 3.4 sec
# epoch 37, loss 0.1004, train acc 0.963, test acc 0.898, time 3.4 sec
# epoch 38, loss 0.1006, train acc 0.963, test acc 0.893, time 3.4 sec
# epoch 39, loss 0.0948, train acc 0.966, test acc 0.900, time 3.4 sec
# epoch 40, loss 0.0927, train acc 0.967, test acc 0.900, time 3.4 sec
# epoch 41, loss 0.0879, train acc 0.968, test acc 0.901, time 3.4 sec
# epoch 42, loss 0.0906, train acc 0.967, test acc 0.898, time 3.4 sec
# epoch 43, loss 0.0850, train acc 0.969, test acc 0.902, time 3.4 sec
# epoch 44, loss 0.0815, train acc 0.971, test acc 0.896, time 3.4 sec
# epoch 45, loss 0.0797, train acc 0.972, test acc 0.898, time 3.4 sec
# epoch 46, loss 0.0770, train acc 0.972, test acc 0.898, time 3.4 sec
# epoch 47, loss 0.0740, train acc 0.974, test acc 0.887, time 3.4 sec
# epoch 48, loss 0.0698, train acc 0.975, test acc 0.893, time 3.4 sec
# epoch 49, loss 0.0699, train acc 0.976, test acc 0.894, time 3.4 sec
# epoch 50, loss 0.0683, train acc 0.976, test acc 0.902, time 3.4 sec
# epoch 51, loss 0.0649, train acc 0.977, test acc 0.895, time 3.4 sec
# epoch 52, loss 0.0623, train acc 0.978, test acc 0.893, time 3.4 sec
# epoch 53, loss 0.0616, train acc 0.978, test acc 0.887, time 3.4 sec
# epoch 54, loss 0.0591, train acc 0.980, test acc 0.899, time 3.4 sec
# epoch 55, loss 0.0583, train acc 0.979, test acc 0.898, time 3.4 sec
# epoch 56, loss 0.0559, train acc 0.980, test acc 0.897, time 3.4 sec
# epoch 57, loss 0.0543, train acc 0.981, test acc 0.901, time 3.4 sec
# epoch 58, loss 0.0517, train acc 0.982, test acc 0.894, time 3.4 sec
# epoch 59, loss 0.0509, train acc 0.983, test acc 0.894, time 3.4 sec
# epoch 60, loss 0.0488, train acc 0.983, test acc 0.899, time 3.4 sec
# epoch 61, loss 0.0473, train acc 0.984, test acc 0.900, time 3.4 sec
# epoch 62, loss 0.0479, train acc 0.983, test acc 0.890, time 3.4 sec
# epoch 63, loss 0.0462, train acc 0.984, test acc 0.902, time 3.4 sec
# epoch 64, loss 0.0435, train acc 0.985, test acc 0.899, time 3.4 sec
# epoch 65, loss 0.0441, train acc 0.984, test acc 0.902, time 3.4 sec
# epoch 66, loss 0.0414, train acc 0.986, test acc 0.903, time 3.4 sec
# epoch 67, loss 0.0389, train acc 0.987, test acc 0.902, time 3.4 sec
# epoch 68, loss 0.0364, train acc 0.988, test acc 0.878, time 3.4 sec
# epoch 69, loss 0.0381, train acc 0.987, test acc 0.899, time 3.4 sec
# epoch 70, loss 0.0383, train acc 0.987, test acc 0.891, time 3.4 sec
# epoch 71, loss 0.0364, train acc 0.988, test acc 0.897, time 3.4 sec
# epoch 72, loss 0.0343, train acc 0.989, test acc 0.899, time 3.4 sec
# epoch 73, loss 0.0351, train acc 0.988, test acc 0.885, time 3.4 sec
# epoch 74, loss 0.0324, train acc 0.989, test acc 0.902, time 3.4 sec
# epoch 75, loss 0.0320, train acc 0.990, test acc 0.900, time 3.4 sec
# epoch 76, loss 0.0266, train acc 0.992, test acc 0.889, time 3.4 sec
# epoch 77, loss 0.0293, train acc 0.991, test acc 0.889, time 3.4 sec
# epoch 78, loss 0.0281, train acc 0.991, test acc 0.901, time 3.4 sec
# epoch 79, loss 0.0270, train acc 0.991, test acc 0.900, time 3.4 sec
# epoch 80, loss 0.0268, train acc 0.991, test acc 0.895, time 3.4 sec
# epoch 81, loss 0.0275, train acc 0.991, test acc 0.881, time 3.4 sec
# epoch 82, loss 0.0266, train acc 0.991, test acc 0.886, time 3.4 sec
# epoch 83, loss 0.0284, train acc 0.991, test acc 0.886, time 3.4 sec
# epoch 84, loss 0.0243, train acc 0.992, test acc 0.896, time 3.4 sec
# epoch 85, loss 0.0242, train acc 0.992, test acc 0.895, time 3.4 sec
# epoch 86, loss 0.0228, train acc 0.993, test acc 0.889, time 3.4 sec
# epoch 87, loss 0.0201, train acc 0.994, test acc 0.890, time 3.4 sec
# epoch 88, loss 0.0236, train acc 0.992, test acc 0.898, time 3.4 sec
# epoch 89, loss 0.0226, train acc 0.993, test acc 0.899, time 3.4 sec
# epoch 90, loss 0.0209, train acc 0.993, test acc 0.897, time 3.4 sec
# epoch 91, loss 0.0197, train acc 0.994, test acc 0.872, time 3.4 sec
# epoch 92, loss 0.0195, train acc 0.994, test acc 0.892, time 3.5 sec
# epoch 93, loss 0.0191, train acc 0.994, test acc 0.896, time 3.4 sec
# epoch 94, loss 0.0173, train acc 0.995, test acc 0.898, time 3.4 sec
# epoch 95, loss 0.0182, train acc 0.994, test acc 0.897, time 3.4 sec
# epoch 96, loss 0.0182, train acc 0.995, test acc 0.891, time 3.4 sec
# epoch 97, loss 0.0176, train acc 0.995, test acc 0.898, time 3.4 sec
# epoch 98, loss 0.0159, train acc 0.995, test acc 0.886, time 3.4 sec
# epoch 99, loss 0.0144, train acc 0.996, test acc 0.892, time 3.4 sec
# epoch 100, loss 0.0147, train acc 0.996, test acc 0.899, time 3.4 sec

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero(), grad_req='null')
        self.gamma = self.params.get('gamma', shape=shape, init=init.One(), grad_req='null')
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
    BatchNorm(6, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
    BatchNorm(16, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
    BatchNorm(120, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(84),
    BatchNorm(84, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(10)
)

lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.6745, train acc 0.765, test acc 0.825, time 3.8 sec
# epoch 2, loss 0.4151, train acc 0.851, test acc 0.830, time 3.7 sec
# epoch 3, loss 0.3659, train acc 0.868, test acc 0.872, time 3.8 sec
# epoch 4, loss 0.3420, train acc 0.877, test acc 0.875, time 3.6 sec
# epoch 5, loss 0.3229, train acc 0.884, test acc 0.841, time 3.7 sec
# epoch 6, loss 0.3110, train acc 0.888, test acc 0.864, time 3.7 sec
# epoch 7, loss 0.2981, train acc 0.893, test acc 0.870, time 3.7 sec
# epoch 8, loss 0.2899, train acc 0.894, test acc 0.861, time 3.7 sec
# epoch 9, loss 0.2802, train acc 0.899, test acc 0.872, time 3.7 sec
# epoch 10, loss 0.2760, train acc 0.900, test acc 0.787, time 3.6 sec
# epoch 11, loss 0.2708, train acc 0.902, test acc 0.857, time 3.6 sec
# epoch 12, loss 0.2622, train acc 0.904, test acc 0.848, time 3.6 sec
# epoch 13, loss 0.2571, train acc 0.907, test acc 0.832, time 3.6 sec
# epoch 14, loss 0.2525, train acc 0.910, test acc 0.886, time 3.7 sec
# epoch 15, loss 0.2493, train acc 0.910, test acc 0.892, time 3.7 sec
# epoch 16, loss 0.2439, train acc 0.912, test acc 0.804, time 3.7 sec
# epoch 17, loss 0.2444, train acc 0.912, test acc 0.869, time 3.7 sec
# epoch 18, loss 0.2369, train acc 0.914, test acc 0.869, time 3.7 sec
# epoch 19, loss 0.2348, train acc 0.914, test acc 0.891, time 3.8 sec
# epoch 20, loss 0.2318, train acc 0.915, test acc 0.887, time 3.7 sec
# epoch 21, loss 0.2299, train acc 0.917, test acc 0.894, time 3.6 sec
# epoch 22, loss 0.2263, train acc 0.918, test acc 0.891, time 3.7 sec
# epoch 23, loss 0.2251, train acc 0.918, test acc 0.849, time 3.7 sec
# epoch 24, loss 0.2210, train acc 0.919, test acc 0.880, time 3.7 sec
# epoch 25, loss 0.2194, train acc 0.920, test acc 0.891, time 3.6 sec
# epoch 26, loss 0.2188, train acc 0.920, test acc 0.896, time 3.7 sec
# epoch 27, loss 0.2145, train acc 0.921, test acc 0.886, time 3.6 sec
# epoch 28, loss 0.2117, train acc 0.922, test acc 0.877, time 3.7 sec
# epoch 29, loss 0.2078, train acc 0.924, test acc 0.901, time 3.7 sec
# epoch 30, loss 0.2061, train acc 0.926, test acc 0.870, time 3.7 sec
# epoch 31, loss 0.2055, train acc 0.924, test acc 0.896, time 3.7 sec
# epoch 32, loss 0.2024, train acc 0.926, test acc 0.899, time 3.8 sec
# epoch 33, loss 0.2028, train acc 0.926, test acc 0.895, time 3.6 sec
# epoch 34, loss 0.2012, train acc 0.926, test acc 0.887, time 3.6 sec
# epoch 35, loss 0.1974, train acc 0.927, test acc 0.858, time 3.6 sec
# epoch 36, loss 0.1964, train acc 0.928, test acc 0.879, time 3.6 sec
# epoch 37, loss 0.1937, train acc 0.929, test acc 0.848, time 3.6 sec
# epoch 38, loss 0.1933, train acc 0.929, test acc 0.866, time 3.6 sec
# epoch 39, loss 0.1928, train acc 0.929, test acc 0.882, time 3.6 sec
# epoch 40, loss 0.1907, train acc 0.929, test acc 0.895, time 3.6 sec
# epoch 41, loss 0.1879, train acc 0.931, test acc 0.887, time 3.6 sec
# epoch 42, loss 0.1831, train acc 0.933, test acc 0.890, time 3.6 sec
# epoch 43, loss 0.1861, train acc 0.931, test acc 0.891, time 3.6 sec
# epoch 44, loss 0.1821, train acc 0.934, test acc 0.894, time 3.6 sec
# epoch 45, loss 0.1814, train acc 0.933, test acc 0.865, time 3.7 sec
# epoch 46, loss 0.1812, train acc 0.934, test acc 0.892, time 3.7 sec
# epoch 47, loss 0.1764, train acc 0.936, test acc 0.892, time 3.7 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f9b607136181> in <module>()
#      44 loss = gluon.loss.SoftmaxCrossEntropyLoss()
#      45 train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
# ---> 46 gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
#
# ~\Downloads\gluon-tutorials-zh\gluonbook\utils.py in train(train_iter, test_iter, net, loss, trainer, ctx, num_epochs, print_batches)
#     187                 l.backward()
#     188             train_acc_sum += sum([(y_hat.argmax(axis=1) == y).sum().asscalar()
# --> 189                                  for y_hat, y in zip(y_hats, ys)])
#     190             train_l_sum += sum([l.sum().asscalar() for l in ls])
#     191             trainer.step(batch_size)
#
# ~\Downloads\gluon-tutorials-zh\gluonbook\utils.py in <listcomp>(.0)
#     187                 l.backward()
#     188             train_acc_sum += sum([(y_hat.argmax(axis=1) == y).sum().asscalar()
# --> 189                                  for y_hat, y in zip(y_hats, ys)])
#     190             train_l_sum += sum([l.sum().asscalar() for l in ls])
#     191             trainer.step(batch_size)
#
# ~\anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asscalar(self)
#    1892         if self.shape != (1,):
#    1893             raise ValueError("The current array is not a scalar")
# -> 1894         return self.asnumpy()[0]
#    1895
#    1896     def astype(self, dtype, copy=True):
#
# ~\anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asnumpy(self)
#    1874             self.handle,
#    1875             data.ctypes.data_as(ctypes.c_void_p),
# -> 1876             ctypes.c_size_t(data.size)))
#    1877         return data
#    1878
#
# KeyboardInterrupt:

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero(), grad_req='null')
        self.gamma = self.params.get('gamma', shape=shape, init=init.One(), grad_req='null')
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),

    nn.Activation('relu'),
 
    nn.MaxPool2D(pool_size=2, strides=2),
           BatchNorm(6, num_dims=4),
    nn.Conv2D(16, kernel_size=5),
   
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
     BatchNorm(16, num_dims=4),
    nn.Dense(120),
    
    nn.Activation('relu'),
    BatchNorm(120, num_dims=2),
    nn.Dense(84),
   
    nn.Activation('relu'),
     BatchNorm(84, num_dims=2),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.5380, train acc 0.809, test acc 0.839, time 3.4 sec
# epoch 2, loss 0.3663, train acc 0.866, test acc 0.869, time 3.4 sec
# epoch 3, loss 0.3273, train acc 0.879, test acc 0.871, time 3.3 sec
# epoch 4, loss 0.3020, train acc 0.889, test acc 0.881, time 3.4 sec
# epoch 5, loss 0.2845, train acc 0.895, test acc 0.840, time 3.3 sec
# epoch 6, loss 0.2722, train acc 0.899, test acc 0.889, time 3.5 sec
# epoch 7, loss 0.2587, train acc 0.905, test acc 0.892, time 3.4 sec
# epoch 8, loss 0.2490, train acc 0.908, test acc 0.896, time 3.3 sec
# epoch 9, loss 0.2390, train acc 0.911, test acc 0.891, time 3.4 sec
# epoch 10, loss 0.2308, train acc 0.915, test acc 0.893, time 3.4 sec
# epoch 11, loss 0.2245, train acc 0.917, test acc 0.897, time 3.4 sec
# epoch 12, loss 0.2159, train acc 0.919, test acc 0.897, time 3.4 sec
# epoch 13, loss 0.2112, train acc 0.920, test acc 0.893, time 3.4 sec
# epoch 14, loss 0.2034, train acc 0.925, test acc 0.900, time 3.4 sec
# epoch 15, loss 0.1992, train acc 0.926, test acc 0.903, time 3.4 sec
# epoch 16, loss 0.1926, train acc 0.928, test acc 0.898, time 3.4 sec
# epoch 17, loss 0.1882, train acc 0.931, test acc 0.902, time 3.3 sec
# epoch 18, loss 0.1836, train acc 0.932, test acc 0.893, time 3.4 sec
# epoch 19, loss 0.1770, train acc 0.935, test acc 0.903, time 3.4 sec
# epoch 20, loss 0.1723, train acc 0.937, test acc 0.897, time 3.4 sec
# epoch 21, loss 0.1676, train acc 0.938, test acc 0.906, time 3.4 sec
# epoch 22, loss 0.1619, train acc 0.941, test acc 0.897, time 3.5 sec
# epoch 23, loss 0.1599, train acc 0.941, test acc 0.899, time 3.5 sec
# epoch 24, loss 0.1570, train acc 0.942, test acc 0.882, time 3.4 sec
# epoch 25, loss 0.1514, train acc 0.944, test acc 0.889, time 3.3 sec
# epoch 26, loss 0.1501, train acc 0.945, test acc 0.910, time 3.3 sec
# epoch 27, loss 0.1441, train acc 0.947, test acc 0.907, time 3.3 sec
# epoch 28, loss 0.1404, train acc 0.948, test acc 0.907, time 3.3 sec
# epoch 29, loss 0.1368, train acc 0.950, test acc 0.907, time 3.3 sec
# epoch 30, loss 0.1350, train acc 0.950, test acc 0.875, time 3.3 sec
# epoch 31, loss 0.1298, train acc 0.953, test acc 0.902, time 3.3 sec
# epoch 32, loss 0.1272, train acc 0.953, test acc 0.889, time 3.3 sec
# epoch 33, loss 0.1231, train acc 0.955, test acc 0.905, time 3.4 sec
# epoch 34, loss 0.1210, train acc 0.956, test acc 0.904, time 3.3 sec
# epoch 35, loss 0.1170, train acc 0.958, test acc 0.908, time 3.4 sec
# epoch 36, loss 0.1140, train acc 0.959, test acc 0.888, time 3.5 sec
# epoch 37, loss 0.1111, train acc 0.960, test acc 0.895, time 3.4 sec
# epoch 38, loss 0.1097, train acc 0.960, test acc 0.903, time 3.4 sec
# epoch 39, loss 0.1085, train acc 0.961, test acc 0.870, time 3.4 sec
# epoch 40, loss 0.1023, train acc 0.963, test acc 0.895, time 3.4 sec
# epoch 41, loss 0.0988, train acc 0.965, test acc 0.902, time 3.3 sec
# epoch 42, loss 0.0980, train acc 0.965, test acc 0.899, time 3.3 sec
# epoch 43, loss 0.0945, train acc 0.966, test acc 0.903, time 3.5 sec
# epoch 44, loss 0.0911, train acc 0.967, test acc 0.902, time 3.4 sec
# epoch 45, loss 0.0917, train acc 0.967, test acc 0.887, time 3.5 sec
# epoch 46, loss 0.0876, train acc 0.969, test acc 0.903, time 3.3 sec
# epoch 47, loss 0.0854, train acc 0.970, test acc 0.901, time 3.3 sec
# epoch 48, loss 0.0829, train acc 0.971, test acc 0.900, time 3.3 sec
# epoch 49, loss 0.0813, train acc 0.971, test acc 0.901, time 3.3 sec
# epoch 50, loss 0.0785, train acc 0.972, test acc 0.897, time 3.3 sec
# epoch 51, loss 0.0758, train acc 0.973, test acc 0.899, time 3.3 sec
# epoch 52, loss 0.0734, train acc 0.974, test acc 0.900, time 3.3 sec
# epoch 53, loss 0.0728, train acc 0.974, test acc 0.896, time 3.3 sec
# epoch 54, loss 0.0705, train acc 0.976, test acc 0.900, time 3.3 sec
# epoch 55, loss 0.0696, train acc 0.975, test acc 0.892, time 3.3 sec
# epoch 56, loss 0.0668, train acc 0.977, test acc 0.900, time 3.3 sec
# epoch 57, loss 0.0652, train acc 0.978, test acc 0.895, time 3.3 sec
# epoch 58, loss 0.0618, train acc 0.979, test acc 0.901, time 3.3 sec
# epoch 59, loss 0.0622, train acc 0.978, test acc 0.897, time 3.6 sec
# epoch 60, loss 0.0595, train acc 0.980, test acc 0.895, time 3.6 sec
# epoch 61, loss 0.0576, train acc 0.981, test acc 0.899, time 3.4 sec
# epoch 62, loss 0.0565, train acc 0.981, test acc 0.869, time 3.4 sec
# epoch 63, loss 0.0566, train acc 0.980, test acc 0.901, time 3.4 sec
# epoch 64, loss 0.0540, train acc 0.982, test acc 0.894, time 3.4 sec
# epoch 65, loss 0.0523, train acc 0.983, test acc 0.889, time 3.4 sec
# epoch 66, loss 0.0524, train acc 0.982, test acc 0.897, time 3.4 sec
# epoch 67, loss 0.0477, train acc 0.985, test acc 0.900, time 3.4 sec
# epoch 68, loss 0.0467, train acc 0.985, test acc 0.897, time 3.4 sec
# epoch 69, loss 0.0452, train acc 0.986, test acc 0.899, time 3.4 sec
# epoch 70, loss 0.0442, train acc 0.986, test acc 0.896, time 3.4 sec
# epoch 71, loss 0.0454, train acc 0.985, test acc 0.892, time 3.4 sec
# epoch 72, loss 0.0418, train acc 0.987, test acc 0.900, time 3.4 sec
# epoch 73, loss 0.0392, train acc 0.988, test acc 0.899, time 3.4 sec
# epoch 74, loss 0.0400, train acc 0.988, test acc 0.900, time 3.4 sec
# epoch 75, loss 0.0406, train acc 0.987, test acc 0.902, time 3.4 sec
# epoch 76, loss 0.0405, train acc 0.987, test acc 0.881, time 3.4 sec
# epoch 77, loss 0.0358, train acc 0.989, test acc 0.901, time 3.4 sec
# epoch 78, loss 0.0367, train acc 0.988, test acc 0.888, time 3.4 sec
# epoch 79, loss 0.0351, train acc 0.989, test acc 0.896, time 3.4 sec
# epoch 80, loss 0.0341, train acc 0.989, test acc 0.899, time 3.4 sec
# epoch 81, loss 0.0344, train acc 0.990, test acc 0.894, time 3.4 sec
# epoch 82, loss 0.0315, train acc 0.991, test acc 0.899, time 3.4 sec
# epoch 83, loss 0.0309, train acc 0.991, test acc 0.897, time 3.4 sec
# epoch 84, loss 0.0326, train acc 0.989, test acc 0.894, time 3.4 sec
# epoch 85, loss 0.0302, train acc 0.991, test acc 0.900, time 3.4 sec
# epoch 86, loss 0.0288, train acc 0.991, test acc 0.896, time 3.4 sec
# epoch 87, loss 0.0292, train acc 0.991, test acc 0.894, time 3.4 sec
# epoch 88, loss 0.0292, train acc 0.991, test acc 0.897, time 3.4 sec
# epoch 89, loss 0.0258, train acc 0.993, test acc 0.901, time 3.4 sec
# epoch 90, loss 0.0248, train acc 0.993, test acc 0.898, time 3.4 sec
# epoch 91, loss 0.0248, train acc 0.993, test acc 0.892, time 3.4 sec
# epoch 92, loss 0.0235, train acc 0.993, test acc 0.895, time 3.4 sec
# epoch 93, loss 0.0231, train acc 0.993, test acc 0.901, time 3.4 sec
# epoch 94, loss 0.0227, train acc 0.993, test acc 0.899, time 3.5 sec
# epoch 95, loss 0.0237, train acc 0.993, test acc 0.897, time 3.4 sec
# epoch 96, loss 0.0209, train acc 0.995, test acc 0.900, time 3.4 sec
# epoch 97, loss 0.0219, train acc 0.994, test acc 0.899, time 3.4 sec
# epoch 98, loss 0.0238, train acc 0.993, test acc 0.901, time 3.4 sec
# epoch 99, loss 0.0194, train acc 0.995, test acc 0.895, time 3.4 sec
# epoch 100, loss 0.0171, train acc 0.996, test acc 0.903, time 3.4 sec

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero(), grad_req='null')
        self.gamma = self.params.get('gamma', shape=shape, init=init.One(), grad_req='null')
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y

net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),

    nn.Activation('sigmoid'),

    nn.MaxPool2D(pool_size=2, strides=2),
            BatchNorm(6, num_dims=4),
    nn.Conv2D(16, kernel_size=5),
   
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
     BatchNorm(16, num_dims=4),
    nn.Dense(120),
    
    nn.Activation('sigmoid'),
    BatchNorm(120, num_dims=2),
    nn.Dense(84),
   
    nn.Activation('sigmoid'),
     BatchNorm(84, num_dims=2),
    nn.Dense(10)
)
lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.8553, train acc 0.735, test acc 0.824, time 3.5 sec
# epoch 2, loss 0.4290, train acc 0.842, test acc 0.855, time 6.5 sec
# epoch 3, loss 0.3659, train acc 0.864, test acc 0.857, time 3.3 sec
# epoch 4, loss 0.3334, train acc 0.876, test acc 0.880, time 3.3 sec
# epoch 5, loss 0.3077, train acc 0.885, test acc 0.878, time 3.4 sec
# epoch 6, loss 0.2886, train acc 0.893, test acc 0.876, time 3.3 sec
# epoch 7, loss 0.2754, train acc 0.896, test acc 0.884, time 3.4 sec
# epoch 8, loss 0.2586, train acc 0.903, test acc 0.844, time 3.4 sec
# epoch 9, loss 0.2509, train acc 0.905, test acc 0.888, time 3.4 sec
# epoch 10, loss 0.2380, train acc 0.910, test acc 0.890, time 3.3 sec
# epoch 11, loss 0.2309, train acc 0.913, test acc 0.889, time 3.4 sec
# epoch 12, loss 0.2235, train acc 0.916, test acc 0.898, time 3.4 sec
# epoch 13, loss 0.2131, train acc 0.920, test acc 0.891, time 3.3 sec
# epoch 14, loss 0.2082, train acc 0.922, test acc 0.892, time 3.4 sec
# epoch 15, loss 0.1965, train acc 0.925, test acc 0.887, time 3.3 sec
# epoch 16, loss 0.1906, train acc 0.929, test acc 0.893, time 3.3 sec
# epoch 17, loss 0.1842, train acc 0.930, test acc 0.898, time 3.3 sec
# epoch 18, loss 0.1782, train acc 0.933, test acc 0.898, time 3.3 sec
# epoch 19, loss 0.1702, train acc 0.936, test acc 0.895, time 3.3 sec
# epoch 20, loss 0.1644, train acc 0.938, test acc 0.855, time 3.3 sec
# epoch 21, loss 0.1584, train acc 0.941, test acc 0.880, time 3.3 sec
# epoch 22, loss 0.1560, train acc 0.942, test acc 0.894, time 3.3 sec
# epoch 23, loss 0.1493, train acc 0.943, test acc 0.895, time 3.3 sec
# epoch 24, loss 0.1444, train acc 0.946, test acc 0.896, time 3.3 sec
# epoch 25, loss 0.1404, train acc 0.948, test acc 0.878, time 3.3 sec
# epoch 26, loss 0.1387, train acc 0.948, test acc 0.897, time 3.2 sec
# epoch 27, loss 0.1299, train acc 0.952, test acc 0.899, time 3.3 sec
# epoch 28, loss 0.1300, train acc 0.950, test acc 0.899, time 3.3 sec
# epoch 29, loss 0.1227, train acc 0.954, test acc 0.896, time 3.3 sec
# epoch 30, loss 0.1188, train acc 0.955, test acc 0.889, time 3.3 sec
# epoch 31, loss 0.1150, train acc 0.956, test acc 0.897, time 3.3 sec
# epoch 32, loss 0.1101, train acc 0.959, test acc 0.900, time 3.2 sec
# epoch 33, loss 0.1072, train acc 0.960, test acc 0.893, time 3.3 sec
# epoch 34, loss 0.1091, train acc 0.960, test acc 0.890, time 3.3 sec
# epoch 35, loss 0.1029, train acc 0.960, test acc 0.900, time 3.3 sec
# epoch 36, loss 0.0952, train acc 0.964, test acc 0.893, time 3.3 sec
# epoch 37, loss 0.0951, train acc 0.964, test acc 0.898, time 3.3 sec
# epoch 38, loss 0.0922, train acc 0.965, test acc 0.896, time 3.2 sec
# epoch 39, loss 0.0887, train acc 0.967, test acc 0.896, time 3.3 sec
# epoch 40, loss 0.0914, train acc 0.965, test acc 0.898, time 3.3 sec
# epoch 41, loss 0.0824, train acc 0.970, test acc 0.896, time 3.2 sec
# epoch 42, loss 0.0777, train acc 0.971, test acc 0.894, time 3.3 sec
# epoch 43, loss 0.0793, train acc 0.971, test acc 0.890, time 3.3 sec
# epoch 44, loss 0.0745, train acc 0.972, test acc 0.896, time 3.3 sec
# epoch 45, loss 0.0692, train acc 0.973, test acc 0.887, time 3.3 sec
# epoch 46, loss 0.0714, train acc 0.973, test acc 0.895, time 3.3 sec
# epoch 47, loss 0.0733, train acc 0.973, test acc 0.894, time 3.2 sec
# epoch 48, loss 0.0741, train acc 0.972, test acc 0.894, time 3.3 sec
# epoch 49, loss 0.0662, train acc 0.975, test acc 0.885, time 3.3 sec
# epoch 50, loss 0.0675, train acc 0.975, test acc 0.893, time 3.3 sec
# epoch 51, loss 0.0601, train acc 0.978, test acc 0.894, time 3.3 sec
# epoch 52, loss 0.0583, train acc 0.978, test acc 0.894, time 3.3 sec
# epoch 53, loss 0.0583, train acc 0.978, test acc 0.888, time 3.3 sec
# epoch 54, loss 0.0609, train acc 0.977, test acc 0.886, time 3.3 sec
# epoch 55, loss 0.0579, train acc 0.978, test acc 0.893, time 3.3 sec
# epoch 56, loss 0.0525, train acc 0.981, test acc 0.883, time 3.3 sec
# epoch 57, loss 0.0616, train acc 0.977, test acc 0.895, time 3.3 sec
# epoch 58, loss 0.0526, train acc 0.980, test acc 0.881, time 3.3 sec
# epoch 59, loss 0.0488, train acc 0.982, test acc 0.890, time 3.3 sec
# epoch 60, loss 0.0459, train acc 0.984, test acc 0.883, time 3.3 sec
# epoch 61, loss 0.0513, train acc 0.982, test acc 0.885, time 3.4 sec
# epoch 62, loss 0.0471, train acc 0.982, test acc 0.893, time 3.3 sec
# epoch 63, loss 0.0564, train acc 0.979, test acc 0.891, time 3.4 sec
# epoch 64, loss 0.0537, train acc 0.981, test acc 0.886, time 3.3 sec
# epoch 65, loss 0.0418, train acc 0.985, test acc 0.876, time 3.4 sec
# epoch 66, loss 0.0433, train acc 0.984, test acc 0.892, time 3.4 sec
# epoch 67, loss 0.0373, train acc 0.987, test acc 0.893, time 3.3 sec
# epoch 68, loss 0.0330, train acc 0.988, test acc 0.896, time 3.4 sec
# epoch 69, loss 0.0423, train acc 0.984, test acc 0.895, time 3.4 sec
# epoch 70, loss 0.0412, train acc 0.985, test acc 0.892, time 3.4 sec
# epoch 71, loss 0.0361, train acc 0.987, test acc 0.889, time 3.4 sec
# epoch 72, loss 0.0368, train acc 0.987, test acc 0.893, time 3.3 sec
# epoch 73, loss 0.0345, train acc 0.988, test acc 0.889, time 3.3 sec
# epoch 74, loss 0.0260, train acc 0.991, test acc 0.867, time 3.3 sec
# epoch 75, loss 0.0408, train acc 0.985, test acc 0.888, time 3.3 sec
# epoch 76, loss 0.0342, train acc 0.988, test acc 0.891, time 3.4 sec
# epoch 77, loss 0.0480, train acc 0.983, test acc 0.886, time 3.3 sec
# epoch 78, loss 0.0383, train acc 0.986, test acc 0.893, time 3.3 sec
# epoch 79, loss 0.0300, train acc 0.990, test acc 0.891, time 3.3 sec
# epoch 80, loss 0.0272, train acc 0.990, test acc 0.894, time 3.4 sec
# epoch 81, loss 0.0194, train acc 0.993, test acc 0.893, time 3.4 sec
# epoch 82, loss 0.0156, train acc 0.995, test acc 0.893, time 3.4 sec
# epoch 83, loss 0.0426, train acc 0.984, test acc 0.893, time 3.3 sec
# epoch 84, loss 0.0277, train acc 0.990, test acc 0.895, time 3.3 sec
# epoch 85, loss 0.0183, train acc 0.994, test acc 0.891, time 3.4 sec
# epoch 86, loss 0.0175, train acc 0.994, test acc 0.891, time 3.4 sec
# epoch 87, loss 0.0250, train acc 0.991, test acc 0.892, time 3.4 sec
# epoch 88, loss 0.0248, train acc 0.991, test acc 0.880, time 3.4 sec
# epoch 89, loss 0.0329, train acc 0.988, test acc 0.872, time 3.4 sec
# epoch 90, loss 0.0542, train acc 0.980, test acc 0.891, time 3.4 sec
# epoch 91, loss 0.0406, train acc 0.985, test acc 0.879, time 3.4 sec
# epoch 92, loss 0.0361, train acc 0.987, test acc 0.893, time 3.4 sec
# epoch 93, loss 0.0178, train acc 0.994, test acc 0.893, time 3.4 sec
# epoch 94, loss 0.0266, train acc 0.991, test acc 0.886, time 3.3 sec
# epoch 95, loss 0.0214, train acc 0.993, test acc 0.888, time 3.5 sec
# epoch 96, loss 0.0323, train acc 0.988, test acc 0.889, time 3.3 sec
# epoch 97, loss 0.0398, train acc 0.987, test acc 0.886, time 3.3 sec
# epoch 98, loss 0.0328, train acc 0.989, test acc 0.890, time 3.3 sec
# epoch 99, loss 0.0147, train acc 0.995, test acc 0.893, time 3.3 sec
# epoch 100, loss 0.0157, train acc 0.995, test acc 0.890, time 3.4 sec

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero(), grad_req='null')
        self.gamma = self.params.get('gamma', shape=shape, init=init.One(), grad_req='null')
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
    BatchNorm(6, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
    BatchNorm(16, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
    BatchNorm(120, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(84),
    BatchNorm(84, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.5653, train acc 0.805, test acc 0.850, time 3.7 sec
# epoch 2, loss 0.3774, train acc 0.864, test acc 0.866, time 3.7 sec
# epoch 3, loss 0.3327, train acc 0.879, test acc 0.879, time 3.7 sec
# epoch 4, loss 0.3068, train acc 0.890, test acc 0.873, time 3.7 sec
# epoch 5, loss 0.2885, train acc 0.894, test acc 0.895, time 3.7 sec
# epoch 6, loss 0.2739, train acc 0.901, test acc 0.879, time 3.7 sec
# epoch 7, loss 0.2638, train acc 0.904, test acc 0.887, time 3.7 sec
# epoch 8, loss 0.2545, train acc 0.906, test acc 0.897, time 3.7 sec
# epoch 9, loss 0.2433, train acc 0.912, test acc 0.896, time 3.7 sec
# epoch 10, loss 0.2360, train acc 0.913, test acc 0.887, time 3.7 sec
# epoch 11, loss 0.2284, train acc 0.917, test acc 0.897, time 3.7 sec
# epoch 12, loss 0.2217, train acc 0.919, test acc 0.900, time 3.7 sec
# epoch 13, loss 0.2159, train acc 0.921, test acc 0.904, time 3.7 sec
# epoch 14, loss 0.2098, train acc 0.924, test acc 0.903, time 3.7 sec
# epoch 15, loss 0.2023, train acc 0.928, test acc 0.891, time 3.7 sec
# epoch 16, loss 0.1990, train acc 0.929, test acc 0.907, time 3.7 sec
# epoch 17, loss 0.1936, train acc 0.930, test acc 0.906, time 3.7 sec
# epoch 18, loss 0.1871, train acc 0.933, test acc 0.904, time 3.7 sec
# epoch 19, loss 0.1854, train acc 0.933, test acc 0.906, time 3.7 sec
# epoch 20, loss 0.1816, train acc 0.934, test acc 0.882, time 3.7 sec
# epoch 21, loss 0.1755, train acc 0.936, test acc 0.905, time 3.7 sec
# epoch 22, loss 0.1719, train acc 0.938, test acc 0.906, time 3.7 sec
# epoch 23, loss 0.1675, train acc 0.940, test acc 0.904, time 3.7 sec
# epoch 24, loss 0.1618, train acc 0.942, test acc 0.905, time 3.7 sec
# epoch 25, loss 0.1606, train acc 0.942, test acc 0.904, time 3.7 sec
# epoch 26, loss 0.1553, train acc 0.945, test acc 0.902, time 3.7 sec
# epoch 27, loss 0.1532, train acc 0.945, test acc 0.892, time 3.7 sec
# epoch 28, loss 0.1502, train acc 0.946, test acc 0.910, time 3.7 sec
# epoch 29, loss 0.1441, train acc 0.948, test acc 0.909, time 3.7 sec
# epoch 30, loss 0.1428, train acc 0.949, test acc 0.908, time 3.7 sec
# epoch 31, loss 0.1402, train acc 0.950, test acc 0.885, time 3.7 sec
# epoch 32, loss 0.1364, train acc 0.951, test acc 0.907, time 3.7 sec
# epoch 33, loss 0.1347, train acc 0.951, test acc 0.892, time 3.7 sec
# epoch 34, loss 0.1298, train acc 0.954, test acc 0.907, time 3.7 sec
# epoch 35, loss 0.1266, train acc 0.956, test acc 0.906, time 3.8 sec
# epoch 36, loss 0.1242, train acc 0.957, test acc 0.897, time 3.8 sec
# epoch 37, loss 0.1218, train acc 0.957, test acc 0.903, time 3.8 sec
# epoch 38, loss 0.1174, train acc 0.959, test acc 0.907, time 3.8 sec
# epoch 39, loss 0.1161, train acc 0.959, test acc 0.899, time 3.8 sec
# epoch 40, loss 0.1129, train acc 0.959, test acc 0.906, time 3.8 sec
# epoch 41, loss 0.1114, train acc 0.961, test acc 0.904, time 3.8 sec
# epoch 42, loss 0.1114, train acc 0.961, test acc 0.902, time 3.7 sec
# epoch 43, loss 0.1066, train acc 0.963, test acc 0.906, time 3.8 sec
# epoch 44, loss 0.1029, train acc 0.964, test acc 0.905, time 3.7 sec
# epoch 45, loss 0.1006, train acc 0.966, test acc 0.907, time 3.7 sec
# epoch 46, loss 0.0987, train acc 0.966, test acc 0.898, time 3.7 sec
# epoch 47, loss 0.0968, train acc 0.966, test acc 0.901, time 3.7 sec
# epoch 48, loss 0.0963, train acc 0.966, test acc 0.901, time 3.7 sec
# epoch 49, loss 0.0949, train acc 0.967, test acc 0.891, time 3.8 sec
# epoch 50, loss 0.0923, train acc 0.968, test acc 0.905, time 3.8 sec
# epoch 51, loss 0.0883, train acc 0.970, test acc 0.902, time 3.7 sec
# epoch 52, loss 0.0878, train acc 0.970, test acc 0.905, time 3.7 sec
# epoch 53, loss 0.0855, train acc 0.971, test acc 0.905, time 3.7 sec
# epoch 54, loss 0.0832, train acc 0.971, test acc 0.907, time 3.7 sec
# epoch 55, loss 0.0828, train acc 0.972, test acc 0.906, time 3.7 sec
# epoch 56, loss 0.0811, train acc 0.973, test acc 0.901, time 3.7 sec
# epoch 57, loss 0.0767, train acc 0.975, test acc 0.883, time 3.7 sec
# epoch 58, loss 0.0766, train acc 0.974, test acc 0.901, time 3.7 sec
# epoch 59, loss 0.0753, train acc 0.975, test acc 0.904, time 3.7 sec
# epoch 60, loss 0.0734, train acc 0.975, test acc 0.889, time 3.7 sec
# epoch 61, loss 0.0738, train acc 0.975, test acc 0.903, time 3.7 sec
# epoch 62, loss 0.0692, train acc 0.977, test acc 0.903, time 3.7 sec
# epoch 63, loss 0.0682, train acc 0.978, test acc 0.901, time 3.7 sec
# epoch 64, loss 0.0678, train acc 0.978, test acc 0.901, time 3.7 sec
# epoch 65, loss 0.0665, train acc 0.978, test acc 0.905, time 3.7 sec
# epoch 66, loss 0.0644, train acc 0.979, test acc 0.904, time 3.7 sec
# epoch 67, loss 0.0635, train acc 0.979, test acc 0.905, time 3.8 sec
# epoch 68, loss 0.0606, train acc 0.981, test acc 0.901, time 3.7 sec
# epoch 69, loss 0.0627, train acc 0.980, test acc 0.894, time 3.7 sec
# epoch 70, loss 0.0599, train acc 0.981, test acc 0.898, time 3.8 sec
# epoch 71, loss 0.0576, train acc 0.982, test acc 0.904, time 3.9 sec
# epoch 72, loss 0.0566, train acc 0.982, test acc 0.903, time 3.9 sec
# epoch 73, loss 0.0569, train acc 0.982, test acc 0.866, time 3.9 sec
# epoch 74, loss 0.0532, train acc 0.983, test acc 0.906, time 3.8 sec
# epoch 75, loss 0.0532, train acc 0.983, test acc 0.900, time 3.9 sec
# epoch 76, loss 0.0521, train acc 0.984, test acc 0.899, time 3.9 sec
# epoch 77, loss 0.0521, train acc 0.984, test acc 0.898, time 3.9 sec
# epoch 78, loss 0.0501, train acc 0.984, test acc 0.901, time 3.8 sec
# epoch 79, loss 0.0486, train acc 0.986, test acc 0.902, time 3.8 sec
# epoch 80, loss 0.0486, train acc 0.985, test acc 0.891, time 3.8 sec
# epoch 81, loss 0.0502, train acc 0.984, test acc 0.900, time 3.8 sec
# epoch 82, loss 0.0469, train acc 0.986, test acc 0.900, time 3.8 sec
# epoch 83, loss 0.0435, train acc 0.988, test acc 0.899, time 3.8 sec
# epoch 84, loss 0.0433, train acc 0.987, test acc 0.899, time 3.8 sec
# epoch 85, loss 0.0429, train acc 0.988, test acc 0.896, time 3.8 sec
# epoch 86, loss 0.0417, train acc 0.988, test acc 0.906, time 3.9 sec
# epoch 87, loss 0.0421, train acc 0.987, test acc 0.901, time 3.8 sec
# epoch 88, loss 0.0412, train acc 0.987, test acc 0.899, time 3.8 sec
# epoch 89, loss 0.0392, train acc 0.989, test acc 0.899, time 3.8 sec
# epoch 90, loss 0.0391, train acc 0.989, test acc 0.905, time 3.8 sec
# epoch 91, loss 0.0386, train acc 0.988, test acc 0.902, time 3.7 sec
# epoch 92, loss 0.0379, train acc 0.989, test acc 0.902, time 3.8 sec
# epoch 93, loss 0.0368, train acc 0.989, test acc 0.903, time 3.9 sec
# epoch 94, loss 0.0358, train acc 0.990, test acc 0.904, time 3.8 sec
# epoch 95, loss 0.0352, train acc 0.990, test acc 0.905, time 3.8 sec
# epoch 96, loss 0.0341, train acc 0.990, test acc 0.908, time 3.7 sec
# epoch 97, loss 0.0363, train acc 0.990, test acc 0.901, time 3.8 sec
# epoch 98, loss 0.0349, train acc 0.990, test acc 0.905, time 3.8 sec
# epoch 99, loss 0.0340, train acc 0.990, test acc 0.907, time 3.8 sec
# epoch 100, loss 0.0320, train acc 0.991, test acc 0.903, time 3.8 sec
