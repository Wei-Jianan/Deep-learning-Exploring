# %%
import mxnet as mx
from mxnet import nd
from mxnet import gluon
# Out:
# C:\Users\weij\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import sys
sys.path.insert(0, '..')
import gluonbook as gb
from mxnet import nd, gluon, init, autograd
from mxnet.gluon import nn

def batch_norm(X, gamma, beta, moving_mean, moving_var,
               eps, momentum):
    # 通过 autograd 来获取是不是在训练环境下。
    if not autograd.is_training():
        # 如果是在预测模式下，直接使用传入的移动平滑均值和方差。
        X_hat = (X - moving_mean) / nd.sqrt(moving_var + eps)
    else:
        assert len(X.shape) in (2, 4)
        # 接在全连接层后情况，计算特征维上的均值和方差。
        if len(X.shape) == 2:
            mean = X.mean(axis=0)
            var = ((X - mean)**2).mean(axis=0)
        # 接在二维卷积层后的情况，计算通道维上（axis=1）的均值和方差。这里我们需要保持 X
        # 的形状以便后面可以正常的做广播运算。
        else:
            mean = X.mean(axis=(0,2,3), keepdims=True)
            var = ((X - mean)**2).mean(axis=(0,2,3), keepdims=True)
        # 训练模式下用当前的均值和方差做归一化。
        X_hat = (X - mean) / nd.sqrt(var + eps)
        # 更新移动平滑均值和方差。
        moving_mean = momentum * moving_mean + (1.0 - momentum) * mean
        moving_var = momentum * moving_var + (1.0 - momentum) * var
    # 拉升和偏移
    Y = gamma * X_hat + beta
    return (Y, moving_mean, moving_var)
# Out:
# C:\Users\weij\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
class BatchNorm(nn.Block):
    def __init__(self, num_features, num_dims, **kwargs):
        super(BatchNorm, self).__init__(**kwargs)
        shape = (1,num_features) if num_dims == 2 else (1,num_features,1,1)
        # 参与求导和更新的模型参数，分别初始化成 0 和 1。
        self.beta = self.params.get('beta', shape=shape, init=init.Zero())
        self.gamma = self.params.get('gamma', shape=shape, init=init.One())
        # 不参与求导的模型参数。全在 CPU 上初始化成 0。
        self.moving_mean = nd.zeros(shape)
        self.moving_variance = nd.zeros(shape)
    def forward(self, X):
        # 如果 X 不在 CPU 上，将 moving_mean 和 moving_varience 复制到对应设备上。
        if self.moving_mean.context != X.context:
            self.moving_mean = self.moving_mean.copyto(X.context)
            self.moving_variance = self.moving_variance.copyto(X.context)
        # 保存更新过的 moving_mean 和 moving_var。
        Y, self.moving_mean, self.moving_variance = batch_norm(
            X, self.gamma.data(), self.beta.data(), self.moving_mean,
            self.moving_variance, eps=1e-5, momentum=0.9)
        return Y

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
#     BatchNorm(6, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
#     BatchNorm(16, num_dims=4),
    nn.Activation('sigmoid'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
#     BatchNorm(120, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(84),
#     BatchNorm(84, num_dims=2),
    nn.Activation('sigmoid'),
    nn.Dense(10)
)
lr = 1.0
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 2.3167, train acc 0.103, test acc 0.187, time 4.7 sec
# epoch 2, loss 1.3419, train acc 0.477, test acc 0.653, time 2.0 sec
# epoch 3, loss 0.8395, train acc 0.673, test acc 0.697, time 1.9 sec
# epoch 4, loss 0.7004, train acc 0.724, test acc 0.738, time 2.0 sec
# epoch 5, loss 0.6251, train acc 0.753, test acc 0.769, time 2.0 sec
# epoch 6, loss 0.5747, train acc 0.772, test acc 0.793, time 2.0 sec
# epoch 7, loss 0.5273, train acc 0.795, test acc 0.797, time 2.0 sec
# epoch 8, loss 0.4979, train acc 0.808, test acc 0.822, time 2.0 sec
# epoch 9, loss 0.4724, train acc 0.820, test acc 0.822, time 2.0 sec
# epoch 10, loss 0.4538, train acc 0.827, test acc 0.831, time 2.0 sec
# epoch 11, loss 0.4316, train acc 0.839, test acc 0.846, time 2.0 sec
# epoch 12, loss 0.4180, train acc 0.844, test acc 0.853, time 2.0 sec
# epoch 13, loss 0.4023, train acc 0.852, test acc 0.859, time 2.0 sec
# epoch 14, loss 0.3872, train acc 0.857, test acc 0.827, time 2.0 sec
# epoch 15, loss 0.3767, train acc 0.861, test acc 0.855, time 2.0 sec
# epoch 16, loss 0.3670, train acc 0.864, test acc 0.863, time 2.0 sec
# epoch 17, loss 0.3583, train acc 0.867, test acc 0.861, time 2.0 sec
# epoch 18, loss 0.3549, train acc 0.869, test acc 0.848, time 2.0 sec
# epoch 19, loss 0.3480, train acc 0.872, test acc 0.862, time 2.0 sec
# epoch 20, loss 0.3375, train acc 0.876, test acc 0.866, time 2.0 sec
# epoch 21, loss 0.3343, train acc 0.875, test acc 0.879, time 2.0 sec
# epoch 22, loss 0.3275, train acc 0.879, test acc 0.876, time 2.0 sec
# epoch 23, loss 0.3250, train acc 0.881, test acc 0.874, time 2.0 sec
# epoch 24, loss 0.3211, train acc 0.881, test acc 0.877, time 2.0 sec
# epoch 25, loss 0.3164, train acc 0.882, test acc 0.881, time 2.0 sec
# epoch 26, loss 0.3096, train acc 0.886, test acc 0.874, time 2.0 sec
# epoch 27, loss 0.3081, train acc 0.887, test acc 0.884, time 2.0 sec
# epoch 28, loss 0.3050, train acc 0.887, test acc 0.884, time 2.0 sec
# epoch 29, loss 0.3034, train acc 0.886, test acc 0.879, time 2.0 sec
# epoch 30, loss 0.3000, train acc 0.889, test acc 0.879, time 2.0 sec
# epoch 31, loss 0.2956, train acc 0.890, test acc 0.885, time 2.0 sec
# epoch 32, loss 0.2920, train acc 0.891, test acc 0.882, time 2.0 sec
# epoch 33, loss 0.2899, train acc 0.892, test acc 0.890, time 2.0 sec
# epoch 34, loss 0.2870, train acc 0.893, test acc 0.885, time 2.0 sec
# epoch 35, loss 0.2835, train acc 0.895, test acc 0.891, time 2.0 sec
# epoch 36, loss 0.2806, train acc 0.895, test acc 0.877, time 2.0 sec
# epoch 37, loss 0.2775, train acc 0.897, test acc 0.896, time 2.0 sec
# epoch 38, loss 0.2756, train acc 0.898, test acc 0.891, time 2.0 sec
# epoch 39, loss 0.2721, train acc 0.898, test acc 0.893, time 2.0 sec
# epoch 40, loss 0.2694, train acc 0.898, test acc 0.886, time 2.0 sec
# epoch 41, loss 0.2688, train acc 0.900, test acc 0.895, time 2.0 sec
# epoch 42, loss 0.2658, train acc 0.902, test acc 0.889, time 2.0 sec
# epoch 43, loss 0.2654, train acc 0.901, test acc 0.881, time 2.0 sec
# epoch 44, loss 0.2623, train acc 0.901, test acc 0.891, time 2.0 sec
# epoch 45, loss 0.2599, train acc 0.903, test acc 0.897, time 2.0 sec
# epoch 46, loss 0.2579, train acc 0.902, test acc 0.894, time 2.0 sec
# epoch 47, loss 0.2558, train acc 0.904, test acc 0.895, time 2.0 sec
# epoch 48, loss 0.2544, train acc 0.904, test acc 0.889, time 1.9 sec
# epoch 49, loss 0.2523, train acc 0.905, test acc 0.897, time 2.0 sec
# epoch 50, loss 0.2504, train acc 0.905, test acc 0.894, time 1.9 sec
# epoch 51, loss 0.2487, train acc 0.906, test acc 0.899, time 1.9 sec
# epoch 52, loss 0.2472, train acc 0.908, test acc 0.889, time 2.0 sec
# epoch 53, loss 0.2451, train acc 0.908, test acc 0.901, time 2.0 sec
# epoch 54, loss 0.2423, train acc 0.909, test acc 0.899, time 2.0 sec
# epoch 55, loss 0.2409, train acc 0.909, test acc 0.892, time 2.0 sec
# epoch 56, loss 0.2399, train acc 0.909, test acc 0.897, time 2.0 sec
# epoch 57, loss 0.2377, train acc 0.911, test acc 0.893, time 2.0 sec
# epoch 58, loss 0.2371, train acc 0.912, test acc 0.901, time 2.0 sec
# epoch 59, loss 0.2355, train acc 0.912, test acc 0.901, time 2.0 sec
# epoch 60, loss 0.2318, train acc 0.913, test acc 0.897, time 2.0 sec
# epoch 61, loss 0.2303, train acc 0.913, test acc 0.900, time 2.0 sec
# epoch 62, loss 0.2291, train acc 0.915, test acc 0.897, time 2.0 sec
# epoch 63, loss 0.2285, train acc 0.914, test acc 0.902, time 2.0 sec
# epoch 64, loss 0.2273, train acc 0.915, test acc 0.898, time 2.0 sec
# epoch 65, loss 0.2253, train acc 0.915, test acc 0.895, time 2.0 sec
# epoch 66, loss 0.2232, train acc 0.916, test acc 0.898, time 2.0 sec
# epoch 67, loss 0.2226, train acc 0.916, test acc 0.903, time 2.0 sec
# epoch 68, loss 0.2198, train acc 0.918, test acc 0.901, time 2.0 sec
# epoch 69, loss 0.2202, train acc 0.917, test acc 0.897, time 2.0 sec
# epoch 70, loss 0.2187, train acc 0.918, test acc 0.901, time 2.0 sec
# epoch 71, loss 0.2178, train acc 0.918, test acc 0.901, time 2.0 sec
# epoch 72, loss 0.2163, train acc 0.918, test acc 0.900, time 2.0 sec
# epoch 73, loss 0.2148, train acc 0.919, test acc 0.892, time 2.0 sec
# epoch 74, loss 0.2117, train acc 0.920, test acc 0.891, time 2.0 sec
# epoch 75, loss 0.2113, train acc 0.921, test acc 0.903, time 2.0 sec
# epoch 76, loss 0.2103, train acc 0.922, test acc 0.901, time 2.0 sec
# epoch 77, loss 0.2091, train acc 0.920, test acc 0.907, time 2.0 sec
# epoch 78, loss 0.2068, train acc 0.922, test acc 0.896, time 2.0 sec
# epoch 79, loss 0.2075, train acc 0.923, test acc 0.896, time 1.9 sec
# epoch 80, loss 0.2050, train acc 0.923, test acc 0.902, time 2.0 sec
# epoch 81, loss 0.2039, train acc 0.923, test acc 0.906, time 2.0 sec
# epoch 82, loss 0.2014, train acc 0.925, test acc 0.899, time 2.0 sec
# epoch 83, loss 0.2004, train acc 0.924, test acc 0.897, time 2.0 sec
# epoch 84, loss 0.1983, train acc 0.927, test acc 0.903, time 2.0 sec
# epoch 85, loss 0.2002, train acc 0.924, test acc 0.897, time 2.0 sec
# epoch 86, loss 0.1978, train acc 0.925, test acc 0.903, time 2.0 sec
# epoch 87, loss 0.1948, train acc 0.927, test acc 0.902, time 1.9 sec
# epoch 88, loss 0.1941, train acc 0.928, test acc 0.898, time 1.9 sec
# epoch 89, loss 0.1915, train acc 0.928, test acc 0.902, time 1.9 sec
# epoch 90, loss 0.1923, train acc 0.928, test acc 0.903, time 2.0 sec
# epoch 91, loss 0.1905, train acc 0.929, test acc 0.906, time 2.0 sec
# epoch 92, loss 0.1890, train acc 0.929, test acc 0.906, time 1.9 sec
# epoch 93, loss 0.1863, train acc 0.930, test acc 0.905, time 2.0 sec
# epoch 94, loss 0.1877, train acc 0.930, test acc 0.902, time 2.0 sec
# epoch 95, loss 0.1875, train acc 0.929, test acc 0.903, time 2.0 sec
# epoch 96, loss 0.1825, train acc 0.932, test acc 0.894, time 1.9 sec
# epoch 97, loss 0.1836, train acc 0.931, test acc 0.904, time 1.9 sec
# epoch 98, loss 0.1819, train acc 0.931, test acc 0.906, time 2.0 sec
# epoch 99, loss 0.1814, train acc 0.932, test acc 0.908, time 2.0 sec
# epoch 100, loss 0.1809, train acc 0.933, test acc 0.902, time 2.0 sec

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
#     BatchNorm(6, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
#     BatchNorm(16, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
#     BatchNorm(120, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(84),
#     BatchNorm(84, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 1.0193, train acc 0.620, test acc 0.700, time 4.7 sec
# epoch 2, loss 0.5965, train acc 0.778, test acc 0.793, time 2.1 sec
# epoch 3, loss 0.5032, train acc 0.815, test acc 0.836, time 2.1 sec
# epoch 4, loss 0.4474, train acc 0.836, test acc 0.851, time 2.1 sec
# epoch 5, loss 0.4068, train acc 0.851, test acc 0.855, time 2.1 sec
# epoch 6, loss 0.3826, train acc 0.859, test acc 0.858, time 2.1 sec
# epoch 7, loss 0.3661, train acc 0.865, test acc 0.868, time 2.1 sec
# epoch 8, loss 0.3512, train acc 0.871, test acc 0.879, time 2.1 sec
# epoch 9, loss 0.3388, train acc 0.875, test acc 0.877, time 2.1 sec
# epoch 10, loss 0.3251, train acc 0.880, test acc 0.879, time 2.1 sec
# epoch 11, loss 0.3177, train acc 0.882, test acc 0.880, time 2.1 sec
# epoch 12, loss 0.3084, train acc 0.885, test acc 0.882, time 2.1 sec
# epoch 13, loss 0.3015, train acc 0.888, test acc 0.882, time 2.1 sec
# epoch 14, loss 0.2964, train acc 0.891, test acc 0.887, time 2.1 sec
# epoch 15, loss 0.2903, train acc 0.893, test acc 0.889, time 2.1 sec
# epoch 16, loss 0.2819, train acc 0.896, test acc 0.893, time 2.1 sec
# epoch 17, loss 0.2757, train acc 0.898, test acc 0.879, time 2.1 sec
# epoch 18, loss 0.2724, train acc 0.899, test acc 0.892, time 2.1 sec
# epoch 19, loss 0.2664, train acc 0.901, test acc 0.890, time 2.1 sec
# epoch 20, loss 0.2608, train acc 0.903, test acc 0.893, time 2.1 sec
# epoch 21, loss 0.2575, train acc 0.904, test acc 0.893, time 2.1 sec
# epoch 22, loss 0.2520, train acc 0.907, test acc 0.887, time 2.1 sec
# epoch 23, loss 0.2508, train acc 0.907, test acc 0.893, time 2.1 sec
# epoch 24, loss 0.2464, train acc 0.908, test acc 0.892, time 2.1 sec
# epoch 25, loss 0.2409, train acc 0.910, test acc 0.890, time 2.1 sec
# epoch 26, loss 0.2374, train acc 0.912, test acc 0.898, time 2.1 sec
# epoch 27, loss 0.2357, train acc 0.912, test acc 0.894, time 2.1 sec
# epoch 28, loss 0.2309, train acc 0.914, test acc 0.882, time 2.1 sec
# epoch 29, loss 0.2297, train acc 0.914, test acc 0.892, time 2.1 sec
# epoch 30, loss 0.2241, train acc 0.917, test acc 0.888, time 2.1 sec
# epoch 31, loss 0.2212, train acc 0.918, test acc 0.899, time 2.1 sec
# epoch 32, loss 0.2181, train acc 0.918, test acc 0.880, time 2.1 sec
# epoch 33, loss 0.2120, train acc 0.921, test acc 0.899, time 2.1 sec
# epoch 34, loss 0.2142, train acc 0.919, test acc 0.891, time 2.1 sec
# epoch 35, loss 0.2092, train acc 0.922, test acc 0.898, time 2.1 sec
# epoch 36, loss 0.2076, train acc 0.922, test acc 0.899, time 2.1 sec
# epoch 37, loss 0.2011, train acc 0.925, test acc 0.900, time 2.1 sec
# epoch 38, loss 0.1990, train acc 0.925, test acc 0.900, time 2.1 sec
# epoch 39, loss 0.1978, train acc 0.926, test acc 0.893, time 2.1 sec
# epoch 40, loss 0.1955, train acc 0.926, test acc 0.896, time 2.1 sec
# epoch 41, loss 0.1920, train acc 0.928, test acc 0.901, time 2.1 sec
# epoch 42, loss 0.1896, train acc 0.929, test acc 0.898, time 2.1 sec
# epoch 43, loss 0.1884, train acc 0.929, test acc 0.899, time 2.1 sec
# epoch 44, loss 0.1833, train acc 0.932, test acc 0.899, time 2.1 sec
# epoch 45, loss 0.1809, train acc 0.932, test acc 0.893, time 2.1 sec
# epoch 46, loss 0.1814, train acc 0.932, test acc 0.898, time 2.1 sec
# epoch 47, loss 0.1760, train acc 0.933, test acc 0.897, time 2.1 sec
# epoch 48, loss 0.1730, train acc 0.934, test acc 0.900, time 2.0 sec
# epoch 49, loss 0.1733, train acc 0.935, test acc 0.895, time 2.1 sec
# epoch 50, loss 0.1696, train acc 0.937, test acc 0.898, time 2.1 sec
# epoch 51, loss 0.1677, train acc 0.937, test acc 0.894, time 2.1 sec
# epoch 52, loss 0.1664, train acc 0.937, test acc 0.900, time 2.1 sec
# epoch 53, loss 0.1640, train acc 0.938, test acc 0.900, time 2.1 sec
# epoch 54, loss 0.1639, train acc 0.938, test acc 0.899, time 2.1 sec
# epoch 55, loss 0.1565, train acc 0.942, test acc 0.899, time 2.1 sec
# epoch 56, loss 0.1569, train acc 0.940, test acc 0.898, time 2.1 sec
# epoch 57, loss 0.1518, train acc 0.943, test acc 0.899, time 2.1 sec
# epoch 58, loss 0.1507, train acc 0.943, test acc 0.894, time 2.1 sec
# epoch 59, loss 0.1513, train acc 0.942, test acc 0.901, time 2.1 sec
# epoch 60, loss 0.1473, train acc 0.945, test acc 0.898, time 2.1 sec
# epoch 61, loss 0.1456, train acc 0.945, test acc 0.894, time 2.1 sec
# epoch 62, loss 0.1408, train acc 0.947, test acc 0.891, time 2.1 sec
# epoch 63, loss 0.1407, train acc 0.947, test acc 0.898, time 2.1 sec
# epoch 64, loss 0.1432, train acc 0.946, test acc 0.901, time 2.1 sec
# epoch 65, loss 0.1362, train acc 0.948, test acc 0.896, time 2.1 sec
# epoch 66, loss 0.1371, train acc 0.949, test acc 0.898, time 2.0 sec
# epoch 67, loss 0.1329, train acc 0.950, test acc 0.894, time 2.1 sec
# epoch 68, loss 0.1333, train acc 0.950, test acc 0.896, time 2.1 sec
# epoch 69, loss 0.1294, train acc 0.951, test acc 0.894, time 2.1 sec
# epoch 70, loss 0.1285, train acc 0.951, test acc 0.901, time 2.1 sec
# epoch 71, loss 0.1236, train acc 0.953, test acc 0.898, time 2.1 sec
# epoch 72, loss 0.1254, train acc 0.952, test acc 0.896, time 2.1 sec
# epoch 73, loss 0.1248, train acc 0.953, test acc 0.902, time 2.1 sec
# epoch 74, loss 0.1202, train acc 0.955, test acc 0.900, time 2.1 sec
# epoch 75, loss 0.1177, train acc 0.955, test acc 0.899, time 2.1 sec
# epoch 76, loss 0.1185, train acc 0.955, test acc 0.889, time 2.1 sec
# epoch 77, loss 0.1150, train acc 0.957, test acc 0.892, time 2.1 sec
# epoch 78, loss 0.1151, train acc 0.957, test acc 0.897, time 2.1 sec
# epoch 79, loss 0.1122, train acc 0.957, test acc 0.899, time 2.1 sec
# epoch 80, loss 0.1074, train acc 0.959, test acc 0.897, time 2.1 sec
# epoch 81, loss 0.1087, train acc 0.959, test acc 0.892, time 2.1 sec
# epoch 82, loss 0.1342, train acc 0.953, test acc 0.891, time 2.1 sec
# epoch 83, loss 0.1049, train acc 0.960, test acc 0.896, time 2.1 sec
# epoch 84, loss 0.1032, train acc 0.962, test acc 0.894, time 2.0 sec
# epoch 85, loss 0.1007, train acc 0.963, test acc 0.889, time 2.1 sec
# epoch 86, loss 0.1009, train acc 0.962, test acc 0.890, time 2.1 sec
# epoch 87, loss 0.1258, train acc 0.956, test acc 0.894, time 2.0 sec
# epoch 88, loss 0.1060, train acc 0.959, test acc 0.882, time 2.1 sec
# epoch 89, loss 0.0958, train acc 0.964, test acc 0.889, time 2.1 sec
# epoch 90, loss 0.0936, train acc 0.965, test acc 0.886, time 2.1 sec
# epoch 91, loss 0.0936, train acc 0.965, test acc 0.894, time 2.0 sec
# epoch 92, loss 0.0927, train acc 0.965, test acc 0.887, time 2.1 sec
# epoch 93, loss 0.0884, train acc 0.967, test acc 0.893, time 2.1 sec
# epoch 94, loss 0.0883, train acc 0.967, test acc 0.899, time 2.1 sec
# epoch 95, loss 0.0910, train acc 0.966, test acc 0.897, time 2.1 sec
# epoch 96, loss 0.0841, train acc 0.969, test acc 0.894, time 2.1 sec
# epoch 97, loss 0.0847, train acc 0.968, test acc 0.896, time 2.1 sec
# epoch 98, loss 0.0838, train acc 0.968, test acc 0.896, time 2.1 sec
# epoch 99, loss 0.0839, train acc 0.968, test acc 0.896, time 2.1 sec
# epoch 100, loss 0.0769, train acc 0.972, test acc 0.896, time 2.1 sec

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
    BatchNorm(6, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
    BatchNorm(16, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
    BatchNorm(120, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(84),
    BatchNorm(84, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.5965, train acc 0.794, test acc 0.838, time 6.7 sec
# epoch 2, loss 0.3792, train acc 0.866, test acc 0.869, time 4.0 sec
# epoch 3, loss 0.3327, train acc 0.880, test acc 0.878, time 4.1 sec
# epoch 4, loss 0.3074, train acc 0.888, test acc 0.875, time 4.0 sec
# epoch 5, loss 0.2876, train acc 0.896, test acc 0.891, time 4.1 sec
# epoch 6, loss 0.2731, train acc 0.900, test acc 0.874, time 4.1 sec
# epoch 7, loss 0.2600, train acc 0.905, test acc 0.895, time 4.1 sec
# epoch 8, loss 0.2504, train acc 0.908, test acc 0.867, time 4.0 sec
# epoch 9, loss 0.2434, train acc 0.910, test acc 0.899, time 3.9 sec
# epoch 10, loss 0.2327, train acc 0.914, test acc 0.891, time 4.0 sec
# epoch 11, loss 0.2264, train acc 0.916, test acc 0.898, time 3.9 sec
# epoch 12, loss 0.2194, train acc 0.919, test acc 0.891, time 3.9 sec
# epoch 13, loss 0.2117, train acc 0.922, test acc 0.898, time 4.0 sec
# epoch 14, loss 0.2068, train acc 0.924, test acc 0.825, time 3.9 sec
# epoch 15, loss 0.2011, train acc 0.926, test acc 0.900, time 4.0 sec
# epoch 16, loss 0.1947, train acc 0.928, test acc 0.902, time 4.0 sec
# epoch 17, loss 0.1915, train acc 0.929, test acc 0.902, time 3.9 sec
# epoch 18, loss 0.1846, train acc 0.932, test acc 0.897, time 3.9 sec
# epoch 19, loss 0.1788, train acc 0.934, test acc 0.884, time 4.0 sec
# epoch 20, loss 0.1748, train acc 0.936, test acc 0.893, time 3.9 sec
# epoch 21, loss 0.1692, train acc 0.938, test acc 0.900, time 3.9 sec
# epoch 22, loss 0.1641, train acc 0.941, test acc 0.891, time 4.0 sec
# epoch 23, loss 0.1607, train acc 0.942, test acc 0.903, time 4.0 sec
# epoch 24, loss 0.1561, train acc 0.943, test acc 0.904, time 4.0 sec
# epoch 25, loss 0.1510, train acc 0.945, test acc 0.894, time 4.0 sec
# epoch 26, loss 0.1474, train acc 0.946, test acc 0.903, time 4.0 sec
# epoch 27, loss 0.1450, train acc 0.948, test acc 0.904, time 4.0 sec
# epoch 28, loss 0.1418, train acc 0.947, test acc 0.907, time 3.9 sec
# epoch 29, loss 0.1367, train acc 0.950, test acc 0.904, time 4.0 sec
# epoch 30, loss 0.1332, train acc 0.952, test acc 0.888, time 3.9 sec
# epoch 31, loss 0.1294, train acc 0.954, test acc 0.899, time 4.0 sec
# epoch 32, loss 0.1283, train acc 0.954, test acc 0.900, time 3.9 sec
# epoch 33, loss 0.1239, train acc 0.955, test acc 0.904, time 4.0 sec
# epoch 34, loss 0.1193, train acc 0.957, test acc 0.892, time 4.0 sec
# epoch 35, loss 0.1167, train acc 0.958, test acc 0.901, time 4.0 sec
# epoch 36, loss 0.1135, train acc 0.960, test acc 0.899, time 4.0 sec
# epoch 37, loss 0.1097, train acc 0.960, test acc 0.904, time 4.0 sec
# epoch 38, loss 0.1079, train acc 0.961, test acc 0.904, time 4.0 sec
# epoch 39, loss 0.1046, train acc 0.963, test acc 0.900, time 4.0 sec
# epoch 40, loss 0.1000, train acc 0.964, test acc 0.902, time 4.0 sec
# epoch 41, loss 0.0983, train acc 0.965, test acc 0.898, time 4.0 sec
# epoch 42, loss 0.0965, train acc 0.966, test acc 0.881, time 3.9 sec
# epoch 43, loss 0.0935, train acc 0.966, test acc 0.891, time 4.0 sec
# epoch 44, loss 0.0912, train acc 0.968, test acc 0.904, time 4.0 sec
# epoch 45, loss 0.0882, train acc 0.968, test acc 0.901, time 4.0 sec
# epoch 46, loss 0.0867, train acc 0.970, test acc 0.902, time 4.0 sec
# epoch 47, loss 0.0843, train acc 0.970, test acc 0.895, time 4.0 sec
# epoch 48, loss 0.0814, train acc 0.971, test acc 0.901, time 4.1 sec
# epoch 49, loss 0.0805, train acc 0.972, test acc 0.897, time 4.0 sec
# epoch 50, loss 0.0769, train acc 0.973, test acc 0.893, time 4.0 sec
# epoch 51, loss 0.0749, train acc 0.974, test acc 0.893, time 4.0 sec
# epoch 52, loss 0.0745, train acc 0.974, test acc 0.903, time 4.0 sec
# epoch 53, loss 0.0738, train acc 0.974, test acc 0.905, time 4.0 sec
# epoch 54, loss 0.0705, train acc 0.975, test acc 0.900, time 4.0 sec
# epoch 55, loss 0.0685, train acc 0.976, test acc 0.900, time 4.0 sec
# epoch 56, loss 0.0645, train acc 0.977, test acc 0.902, time 4.0 sec
# epoch 57, loss 0.0640, train acc 0.978, test acc 0.881, time 4.0 sec
# epoch 58, loss 0.0617, train acc 0.979, test acc 0.895, time 4.0 sec
# epoch 59, loss 0.0596, train acc 0.980, test acc 0.899, time 4.0 sec
# epoch 60, loss 0.0561, train acc 0.981, test acc 0.895, time 4.0 sec
# epoch 61, loss 0.0584, train acc 0.980, test acc 0.905, time 4.0 sec
# epoch 62, loss 0.0545, train acc 0.981, test acc 0.893, time 4.0 sec
# epoch 63, loss 0.0539, train acc 0.982, test acc 0.900, time 4.0 sec
# epoch 64, loss 0.0509, train acc 0.983, test acc 0.885, time 4.0 sec
# epoch 65, loss 0.0515, train acc 0.982, test acc 0.899, time 4.0 sec
# epoch 66, loss 0.0506, train acc 0.983, test acc 0.901, time 4.0 sec
# epoch 67, loss 0.0480, train acc 0.984, test acc 0.896, time 4.0 sec
# epoch 68, loss 0.0470, train acc 0.984, test acc 0.901, time 4.1 sec
# epoch 69, loss 0.0468, train acc 0.984, test acc 0.902, time 4.0 sec
# epoch 70, loss 0.0430, train acc 0.986, test acc 0.872, time 4.0 sec
# epoch 71, loss 0.0427, train acc 0.986, test acc 0.900, time 4.0 sec
# epoch 72, loss 0.0414, train acc 0.987, test acc 0.896, time 4.0 sec
# epoch 73, loss 0.0382, train acc 0.988, test acc 0.898, time 4.0 sec
# epoch 74, loss 0.0395, train acc 0.987, test acc 0.902, time 4.0 sec
# epoch 75, loss 0.0381, train acc 0.988, test acc 0.896, time 4.0 sec
# epoch 76, loss 0.0370, train acc 0.988, test acc 0.899, time 4.0 sec
# epoch 77, loss 0.0341, train acc 0.990, test acc 0.899, time 4.0 sec
# epoch 78, loss 0.0340, train acc 0.989, test acc 0.900, time 4.0 sec
# epoch 79, loss 0.0337, train acc 0.989, test acc 0.897, time 4.0 sec
# epoch 80, loss 0.0341, train acc 0.989, test acc 0.890, time 4.0 sec
# epoch 81, loss 0.0339, train acc 0.989, test acc 0.898, time 4.0 sec
# epoch 82, loss 0.0302, train acc 0.991, test acc 0.904, time 4.0 sec
# epoch 83, loss 0.0293, train acc 0.991, test acc 0.897, time 4.0 sec
# epoch 84, loss 0.0294, train acc 0.991, test acc 0.900, time 4.0 sec
# epoch 85, loss 0.0280, train acc 0.992, test acc 0.901, time 4.0 sec
# epoch 86, loss 0.0272, train acc 0.992, test acc 0.904, time 4.0 sec
# epoch 87, loss 0.0259, train acc 0.992, test acc 0.905, time 4.0 sec
# epoch 88, loss 0.0234, train acc 0.993, test acc 0.897, time 4.0 sec
# epoch 89, loss 0.0261, train acc 0.992, test acc 0.901, time 4.0 sec
# epoch 90, loss 0.0261, train acc 0.992, test acc 0.869, time 4.0 sec
# epoch 91, loss 0.0235, train acc 0.993, test acc 0.898, time 4.0 sec
# epoch 92, loss 0.0231, train acc 0.994, test acc 0.897, time 4.0 sec
# epoch 93, loss 0.0227, train acc 0.993, test acc 0.896, time 4.0 sec
# epoch 94, loss 0.0235, train acc 0.993, test acc 0.899, time 4.0 sec
# epoch 95, loss 0.0205, train acc 0.995, test acc 0.899, time 4.0 sec
# epoch 96, loss 0.0230, train acc 0.994, test acc 0.900, time 4.0 sec
# epoch 97, loss 0.0215, train acc 0.994, test acc 0.887, time 4.0 sec
# epoch 98, loss 0.0195, train acc 0.995, test acc 0.901, time 4.0 sec
# epoch 99, loss 0.0180, train acc 0.995, test acc 0.895, time 3.9 sec
# epoch 100, loss 0.0183, train acc 0.995, test acc 0.899, time 4.0 sec

# %%
net = nn.Sequential()
net.add(
    nn.Conv2D(6, kernel_size=5),
    BatchNorm(6, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Conv2D(16, kernel_size=5),
    BatchNorm(16, num_dims=4),
    nn.Activation('relu'),
    nn.MaxPool2D(pool_size=2, strides=2),
    nn.Dense(120),
    BatchNorm(120, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(84),
    BatchNorm(84, num_dims=2),
    nn.Activation('relu'),
    nn.Dense(10)
)
lr = 0.1
ctx = gb.try_gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=256)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=100)
# Out:
# training on gpu(0)
# epoch 1, loss 0.5607, train acc 0.806, test acc 0.852, time 4.7 sec
# epoch 2, loss 0.3746, train acc 0.865, test acc 0.870, time 4.1 sec
# epoch 3, loss 0.3338, train acc 0.879, test acc 0.877, time 4.0 sec
# epoch 4, loss 0.3074, train acc 0.888, test acc 0.883, time 4.0 sec
# epoch 5, loss 0.2917, train acc 0.894, test acc 0.867, time 4.0 sec
# epoch 6, loss 0.2783, train acc 0.898, test acc 0.886, time 4.0 sec
# epoch 7, loss 0.2675, train acc 0.902, test acc 0.888, time 4.0 sec
# epoch 8, loss 0.2586, train acc 0.906, test acc 0.893, time 4.0 sec
# epoch 9, loss 0.2501, train acc 0.908, test acc 0.889, time 4.0 sec
# epoch 10, loss 0.2430, train acc 0.910, test acc 0.895, time 3.9 sec
# epoch 11, loss 0.2354, train acc 0.914, test acc 0.905, time 4.0 sec
# epoch 12, loss 0.2301, train acc 0.915, test acc 0.897, time 4.0 sec
# epoch 13, loss 0.2230, train acc 0.919, test acc 0.896, time 4.0 sec
# epoch 14, loss 0.2177, train acc 0.920, test acc 0.897, time 4.0 sec
# epoch 15, loss 0.2117, train acc 0.922, test acc 0.865, time 4.0 sec
# epoch 16, loss 0.2085, train acc 0.924, test acc 0.896, time 4.0 sec
# epoch 17, loss 0.2020, train acc 0.926, test acc 0.899, time 4.0 sec
# epoch 18, loss 0.1984, train acc 0.927, test acc 0.900, time 4.0 sec
# epoch 19, loss 0.1936, train acc 0.928, test acc 0.891, time 4.0 sec
# epoch 20, loss 0.1877, train acc 0.931, test acc 0.895, time 4.0 sec
# epoch 21, loss 0.1847, train acc 0.933, test acc 0.894, time 4.0 sec
# epoch 22, loss 0.1820, train acc 0.933, test acc 0.891, time 4.0 sec
# epoch 23, loss 0.1751, train acc 0.936, test acc 0.863, time 3.9 sec
# epoch 24, loss 0.1724, train acc 0.938, test acc 0.906, time 4.0 sec
# epoch 25, loss 0.1673, train acc 0.939, test acc 0.904, time 4.0 sec
# epoch 26, loss 0.1633, train acc 0.940, test acc 0.910, time 4.0 sec
# epoch 27, loss 0.1600, train acc 0.941, test acc 0.905, time 4.0 sec
# epoch 28, loss 0.1572, train acc 0.942, test acc 0.899, time 4.0 sec
# epoch 29, loss 0.1516, train acc 0.945, test acc 0.901, time 4.0 sec
# epoch 30, loss 0.1491, train acc 0.946, test acc 0.895, time 4.0 sec
# epoch 31, loss 0.1495, train acc 0.945, test acc 0.899, time 4.0 sec
# epoch 32, loss 0.1426, train acc 0.948, test acc 0.899, time 4.0 sec
# epoch 33, loss 0.1403, train acc 0.949, test acc 0.910, time 3.9 sec
# epoch 34, loss 0.1365, train acc 0.951, test acc 0.906, time 4.0 sec
# epoch 35, loss 0.1326, train acc 0.952, test acc 0.897, time 4.0 sec
# epoch 36, loss 0.1315, train acc 0.952, test acc 0.902, time 4.0 sec
# epoch 37, loss 0.1282, train acc 0.954, test acc 0.901, time 4.1 sec
# epoch 38, loss 0.1264, train acc 0.953, test acc 0.898, time 4.0 sec
# epoch 39, loss 0.1229, train acc 0.955, test acc 0.899, time 4.0 sec
# epoch 40, loss 0.1196, train acc 0.957, test acc 0.894, time 4.0 sec
# epoch 41, loss 0.1193, train acc 0.957, test acc 0.905, time 4.0 sec
# epoch 42, loss 0.1145, train acc 0.959, test acc 0.905, time 4.0 sec
# epoch 43, loss 0.1114, train acc 0.960, test acc 0.865, time 4.0 sec
# epoch 44, loss 0.1091, train acc 0.960, test acc 0.880, time 4.0 sec
# epoch 45, loss 0.1079, train acc 0.961, test acc 0.909, time 4.0 sec
# epoch 46, loss 0.1058, train acc 0.962, test acc 0.902, time 4.0 sec
# epoch 47, loss 0.1021, train acc 0.963, test acc 0.904, time 4.0 sec
# epoch 48, loss 0.0987, train acc 0.965, test acc 0.897, time 4.0 sec
# epoch 49, loss 0.0981, train acc 0.965, test acc 0.901, time 4.0 sec
# epoch 50, loss 0.0968, train acc 0.965, test acc 0.903, time 4.0 sec
# epoch 51, loss 0.0933, train acc 0.966, test acc 0.905, time 4.1 sec
# epoch 52, loss 0.0915, train acc 0.967, test acc 0.900, time 4.0 sec
# epoch 53, loss 0.0914, train acc 0.967, test acc 0.899, time 4.0 sec
# epoch 54, loss 0.0876, train acc 0.968, test acc 0.903, time 4.1 sec
# epoch 55, loss 0.0832, train acc 0.970, test acc 0.897, time 4.0 sec
# epoch 56, loss 0.0828, train acc 0.971, test acc 0.904, time 4.1 sec
# epoch 57, loss 0.0799, train acc 0.972, test acc 0.903, time 4.1 sec
# epoch 58, loss 0.0800, train acc 0.972, test acc 0.902, time 4.1 sec
# epoch 59, loss 0.0758, train acc 0.973, test acc 0.894, time 4.1 sec
# epoch 60, loss 0.0762, train acc 0.973, test acc 0.897, time 4.0 sec
# epoch 61, loss 0.0746, train acc 0.974, test acc 0.904, time 4.1 sec
# epoch 62, loss 0.0729, train acc 0.975, test acc 0.902, time 4.0 sec
# epoch 63, loss 0.0703, train acc 0.975, test acc 0.896, time 4.1 sec
# epoch 64, loss 0.0701, train acc 0.976, test acc 0.894, time 4.0 sec
# epoch 65, loss 0.0670, train acc 0.976, test acc 0.896, time 4.0 sec
# epoch 66, loss 0.0659, train acc 0.977, test acc 0.896, time 4.1 sec
# epoch 67, loss 0.0638, train acc 0.978, test acc 0.897, time 4.1 sec
# epoch 68, loss 0.0616, train acc 0.979, test acc 0.902, time 4.1 sec
# epoch 69, loss 0.0614, train acc 0.978, test acc 0.894, time 4.0 sec
# epoch 70, loss 0.0620, train acc 0.978, test acc 0.897, time 4.0 sec
# epoch 71, loss 0.0588, train acc 0.980, test acc 0.896, time 4.1 sec
# epoch 72, loss 0.0572, train acc 0.980, test acc 0.880, time 4.0 sec
# epoch 73, loss 0.0555, train acc 0.981, test acc 0.904, time 4.0 sec
# epoch 74, loss 0.0536, train acc 0.982, test acc 0.903, time 4.0 sec
# epoch 75, loss 0.0535, train acc 0.982, test acc 0.888, time 4.1 sec
# epoch 76, loss 0.0522, train acc 0.982, test acc 0.901, time 4.0 sec
# epoch 77, loss 0.0523, train acc 0.982, test acc 0.903, time 4.0 sec
# epoch 78, loss 0.0523, train acc 0.982, test acc 0.888, time 4.1 sec
# epoch 79, loss 0.0492, train acc 0.983, test acc 0.904, time 4.1 sec
# epoch 80, loss 0.0476, train acc 0.984, test acc 0.901, time 4.1 sec
# epoch 81, loss 0.0459, train acc 0.985, test acc 0.903, time 4.1 sec
# epoch 82, loss 0.0452, train acc 0.985, test acc 0.905, time 4.1 sec
# epoch 83, loss 0.0441, train acc 0.985, test acc 0.895, time 4.1 sec
# epoch 84, loss 0.0430, train acc 0.986, test acc 0.901, time 4.1 sec
# epoch 85, loss 0.0422, train acc 0.986, test acc 0.898, time 4.0 sec
# epoch 86, loss 0.0425, train acc 0.986, test acc 0.889, time 4.1 sec
# epoch 87, loss 0.0406, train acc 0.986, test acc 0.900, time 4.1 sec
# epoch 88, loss 0.0386, train acc 0.987, test acc 0.900, time 4.0 sec
# epoch 89, loss 0.0405, train acc 0.986, test acc 0.903, time 4.0 sec
# epoch 90, loss 0.0363, train acc 0.988, test acc 0.897, time 4.1 sec
# epoch 91, loss 0.0358, train acc 0.989, test acc 0.897, time 4.1 sec
# epoch 92, loss 0.0359, train acc 0.989, test acc 0.900, time 4.1 sec
# epoch 93, loss 0.0342, train acc 0.989, test acc 0.901, time 3.9 sec
# epoch 94, loss 0.0341, train acc 0.989, test acc 0.902, time 4.0 sec
# epoch 95, loss 0.0327, train acc 0.989, test acc 0.898, time 4.1 sec
# epoch 96, loss 0.0315, train acc 0.990, test acc 0.899, time 4.0 sec
# epoch 97, loss 0.0314, train acc 0.990, test acc 0.902, time 4.1 sec
# epoch 98, loss 0.0286, train acc 0.991, test acc 0.902, time 4.0 sec
# epoch 99, loss 0.0309, train acc 0.990, test acc 0.899, time 4.1 sec
# epoch 100, loss 0.0329, train acc 0.989, test acc 0.900, time 4.1 sec
