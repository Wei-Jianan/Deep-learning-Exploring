# %%
import sys
sys.path.insert(0, '..')
import gluonbook as gb
from mxnet import nd, gluon, init
from mxnet.gluon import nn

def nin_block(num_channels, kernel_size, strides, padding):
    blk = nn.Sequential()
    blk.add(nn.Conv2D(num_channels, kernel_size,
                      strides, padding, activation='relu'),
            nn.Conv2D(num_channels, kernel_size=1, activation='relu'),
            nn.Conv2D(num_channels, kernel_size=1, activation='relu'))
    return blk

# %%
net = nn.Sequential()
net.add(
    nin_block(96, kernel_size=11, strides=4, padding=0),
    nn.MaxPool2D(pool_size=3, strides=2),
    nin_block(256, kernel_size=5, strides=1, padding=2),
    nn.MaxPool2D(pool_size=3, strides=2),
    nin_block(384, kernel_size=3, strides=1, padding=1),
    nn.MaxPool2D(pool_size=3, strides=2), nn.Dropout(.5),
    # 标签类数是 10。
    nin_block(10, kernel_size=3, strides=1, padding=1),
    # 全局平均池化层将窗口形状自动设置成输出的高和宽。
    nn.GlobalAvgPool2D(),
    # 将四维的输出转成二维的输出，其形状为（批量大小，10）。
    nn.Flatten())

# %%
# X = nd.random.uniform(shape=(1,1,224,224))
# net.initialize()
# for layer in net:
#     X = layer(X)
#     print(layer.name, 'output shape:\t', X.shape)

# %%
lr = .1
ctx = gb.try_gpu()
net.initialize( ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
loss = gluon.loss.SoftmaxCrossEntropyLoss()
train_data, test_data = gb.load_data_fashion_mnist(batch_size=128, resize=224)
gb.train(train_data, test_data, net, loss, trainer, ctx, num_epochs=200)
# Out:
# C:\Program Files\Anaconda3\envs\ML\lib\site-packages\mxnet\gluon\data\vision.py:118: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   label = np.fromstring(fin.read(), dtype=np.uint8).astype(np.int32)
# C:\Program Files\Anaconda3\envs\ML\lib\site-packages\mxnet\gluon\data\vision.py:122: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   data = np.fromstring(fin.read(), dtype=np.uint8)
# training on  gpu(0)
# epoch 1, loss 1.9891, train acc 0.257, test acc 0.425, time 147.0 sec
# epoch 2, loss 1.3507, train acc 0.477, test acc 0.549, time 134.2 sec
# epoch 3, loss 0.8509, train acc 0.677, test acc 0.714, time 134.8 sec
# epoch 4, loss 0.6455, train acc 0.758, test acc 0.801, time 134.8 sec
# epoch 5, loss 0.5510, train acc 0.792, test acc 0.823, time 134.7 sec
# epoch 6, loss 0.4877, train acc 0.818, test acc 0.833, time 134.6 sec
# epoch 7, loss 0.4507, train acc 0.833, test acc 0.857, time 134.6 sec
# epoch 8, loss 0.4144, train acc 0.846, test acc 0.860, time 134.7 sec
# epoch 9, loss 0.3887, train acc 0.856, test acc 0.876, time 134.7 sec
# epoch 10, loss 0.3691, train acc 0.863, test acc 0.856, time 134.6 sec
# epoch 11, loss 0.3571, train acc 0.868, test acc 0.877, time 134.6 sec
# epoch 12, loss 0.3396, train acc 0.874, test acc 0.890, time 134.8 sec
# epoch 13, loss 0.3305, train acc 0.878, test acc 0.888, time 135.8 sec
# epoch 14, loss 0.3186, train acc 0.882, test acc 0.891, time 135.3 sec
# epoch 15, loss 0.3064, train acc 0.886, test acc 0.894, time 134.5 sec
# epoch 16, loss 0.2994, train acc 0.890, test acc 0.901, time 134.7 sec
# epoch 17, loss 0.2918, train acc 0.892, test acc 0.896, time 134.6 sec
# epoch 18, loss 0.2816, train acc 0.896, test acc 0.904, time 134.7 sec
# epoch 19, loss 0.2742, train acc 0.899, test acc 0.909, time 135.9 sec
# epoch 20, loss 0.2655, train acc 0.902, test acc 0.902, time 134.4 sec
# epoch 21, loss 0.2628, train acc 0.904, test acc 0.910, time 134.4 sec
# epoch 22, loss 0.2534, train acc 0.907, test acc 0.913, time 134.9 sec
# epoch 23, loss 0.2507, train acc 0.908, test acc 0.909, time 134.7 sec
# epoch 24, loss 0.2440, train acc 0.910, test acc 0.910, time 134.5 sec
# epoch 25, loss 0.2386, train acc 0.913, test acc 0.916, time 134.4 sec
# epoch 26, loss 0.2317, train acc 0.914, test acc 0.919, time 134.5 sec
# epoch 27, loss 0.2295, train acc 0.916, test acc 0.912, time 134.4 sec
# epoch 28, loss 0.2241, train acc 0.917, test acc 0.919, time 134.5 sec
# epoch 29, loss 0.2187, train acc 0.919, test acc 0.919, time 134.7 sec
# epoch 30, loss 0.2147, train acc 0.921, test acc 0.921, time 134.6 sec
# epoch 31, loss 0.2083, train acc 0.924, test acc 0.922, time 134.5 sec
# epoch 32, loss 0.2034, train acc 0.925, test acc 0.920, time 134.5 sec
# epoch 33, loss 0.2035, train acc 0.924, test acc 0.912, time 134.8 sec
# epoch 34, loss 0.1990, train acc 0.927, test acc 0.922, time 134.5 sec
# epoch 35, loss 0.1958, train acc 0.928, test acc 0.924, time 134.9 sec
# epoch 36, loss 0.1917, train acc 0.930, test acc 0.914, time 134.5 sec
# epoch 37, loss 0.1847, train acc 0.931, test acc 0.927, time 134.8 sec
# epoch 38, loss 0.1847, train acc 0.932, test acc 0.927, time 134.6 sec
# epoch 39, loss 0.1797, train acc 0.933, test acc 0.921, time 134.6 sec
# epoch 40, loss 0.1757, train acc 0.935, test acc 0.927, time 134.6 sec
# epoch 41, loss 0.1723, train acc 0.937, test acc 0.930, time 134.8 sec
# epoch 42, loss 0.1703, train acc 0.938, test acc 0.925, time 134.9 sec
# epoch 43, loss 0.1652, train acc 0.939, test acc 0.928, time 134.8 sec
# epoch 44, loss 0.1656, train acc 0.938, test acc 0.929, time 134.8 sec
# epoch 45, loss 0.1616, train acc 0.940, test acc 0.930, time 134.4 sec
# epoch 46, loss 0.1580, train acc 0.941, test acc 0.925, time 134.6 sec
# epoch 47, loss 0.1566, train acc 0.942, test acc 0.928, time 134.8 sec
# epoch 48, loss 0.1525, train acc 0.943, test acc 0.932, time 135.0 sec
# epoch 49, loss 0.1498, train acc 0.945, test acc 0.919, time 134.5 sec
# epoch 50, loss 0.1455, train acc 0.946, test acc 0.930, time 134.9 sec
# epoch 51, loss 0.1416, train acc 0.948, test acc 0.930, time 134.6 sec
# epoch 52, loss 0.1397, train acc 0.948, test acc 0.925, time 134.6 sec
# epoch 53, loss 0.1369, train acc 0.949, test acc 0.931, time 134.8 sec
# epoch 54, loss 0.1340, train acc 0.949, test acc 0.928, time 134.7 sec
# epoch 55, loss 0.1293, train acc 0.952, test acc 0.929, time 134.6 sec
# epoch 56, loss 0.1293, train acc 0.952, test acc 0.931, time 134.6 sec
# epoch 57, loss 0.1269, train acc 0.953, test acc 0.926, time 134.5 sec
# epoch 58, loss 0.1255, train acc 0.953, test acc 0.932, time 134.5 sec
# epoch 59, loss 0.1233, train acc 0.953, test acc 0.933, time 134.7 sec
# epoch 60, loss 0.1201, train acc 0.955, test acc 0.930, time 134.7 sec
# epoch 61, loss 0.1166, train acc 0.956, test acc 0.931, time 134.8 sec
# epoch 62, loss 0.1153, train acc 0.956, test acc 0.935, time 134.6 sec
# epoch 63, loss 0.1124, train acc 0.958, test acc 0.930, time 134.8 sec
# epoch 64, loss 0.1119, train acc 0.958, test acc 0.926, time 134.6 sec
# epoch 65, loss 0.1085, train acc 0.960, test acc 0.928, time 134.6 sec
# epoch 66, loss 0.1065, train acc 0.960, test acc 0.934, time 134.6 sec
# epoch 67, loss 0.1025, train acc 0.962, test acc 0.933, time 134.5 sec
# epoch 68, loss 0.1015, train acc 0.963, test acc 0.932, time 134.5 sec
# epoch 69, loss 0.0987, train acc 0.962, test acc 0.926, time 134.5 sec
# epoch 70, loss 0.0984, train acc 0.963, test acc 0.927, time 134.6 sec
# epoch 71, loss 0.0950, train acc 0.965, test acc 0.931, time 134.5 sec
# epoch 72, loss 0.0942, train acc 0.965, test acc 0.935, time 134.8 sec
# epoch 73, loss 0.0915, train acc 0.966, test acc 0.921, time 134.6 sec
# epoch 74, loss 0.0900, train acc 0.966, test acc 0.930, time 134.5 sec
# epoch 75, loss 0.0870, train acc 0.968, test acc 0.933, time 134.8 sec
# epoch 76, loss 0.0857, train acc 0.968, test acc 0.934, time 134.7 sec
# epoch 77, loss 0.0829, train acc 0.969, test acc 0.934, time 134.9 sec
# epoch 78, loss 0.0826, train acc 0.969, test acc 0.929, time 134.9 sec
# epoch 79, loss 0.0811, train acc 0.969, test acc 0.932, time 134.7 sec
# epoch 80, loss 0.0808, train acc 0.970, test acc 0.936, time 134.7 sec
# epoch 81, loss 0.0795, train acc 0.970, test acc 0.932, time 134.6 sec
# epoch 82, loss 0.0785, train acc 0.970, test acc 0.937, time 134.9 sec
# epoch 83, loss 0.0735, train acc 0.973, test acc 0.933, time 134.6 sec
# epoch 84, loss 0.0713, train acc 0.974, test acc 0.935, time 134.8 sec
# epoch 85, loss 0.0710, train acc 0.973, test acc 0.927, time 134.8 sec
# epoch 86, loss 0.0700, train acc 0.974, test acc 0.930, time 134.6 sec
# epoch 87, loss 0.0679, train acc 0.975, test acc 0.931, time 134.8 sec
# epoch 88, loss 0.0677, train acc 0.975, test acc 0.933, time 134.4 sec
# epoch 89, loss 0.0627, train acc 0.976, test acc 0.934, time 134.7 sec
# epoch 90, loss 0.0662, train acc 0.975, test acc 0.931, time 134.6 sec
# epoch 91, loss 0.0614, train acc 0.977, test acc 0.935, time 134.6 sec
# epoch 92, loss 0.0620, train acc 0.977, test acc 0.934, time 134.9 sec
# epoch 93, loss 0.0621, train acc 0.976, test acc 0.932, time 134.8 sec
# epoch 94, loss 0.0588, train acc 0.978, test acc 0.934, time 134.8 sec
# epoch 95, loss 0.0587, train acc 0.978, test acc 0.931, time 134.8 sec
# epoch 96, loss 0.0550, train acc 0.980, test acc 0.933, time 134.5 sec
# epoch 97, loss 0.0548, train acc 0.980, test acc 0.937, time 134.5 sec
# epoch 98, loss 0.0541, train acc 0.980, test acc 0.931, time 134.6 sec
# epoch 99, loss 0.0526, train acc 0.981, test acc 0.933, time 134.6 sec
# epoch 100, loss 0.0516, train acc 0.981, test acc 0.936, time 134.6 sec
# epoch 101, loss 0.0538, train acc 0.980, test acc 0.933, time 134.5 sec
# epoch 102, loss 0.0517, train acc 0.981, test acc 0.934, time 134.7 sec
# epoch 103, loss 0.0494, train acc 0.981, test acc 0.929, time 134.9 sec
# epoch 104, loss 0.0453, train acc 0.983, test acc 0.936, time 134.7 sec
# epoch 105, loss 0.0481, train acc 0.983, test acc 0.935, time 134.7 sec
# epoch 106, loss 0.0473, train acc 0.983, test acc 0.939, time 134.5 sec
# epoch 107, loss 0.0458, train acc 0.983, test acc 0.930, time 134.7 sec
# epoch 108, loss 0.0442, train acc 0.984, test acc 0.937, time 134.8 sec
# epoch 109, loss 0.0441, train acc 0.984, test acc 0.934, time 134.7 sec
# epoch 110, loss 0.0429, train acc 0.984, test acc 0.935, time 134.5 sec
# epoch 111, loss 0.0399, train acc 0.985, test acc 0.936, time 134.9 sec
# epoch 112, loss 0.0433, train acc 0.984, test acc 0.936, time 135.0 sec
# epoch 113, loss 0.0430, train acc 0.984, test acc 0.935, time 134.6 sec
# epoch 114, loss 0.0398, train acc 0.985, test acc 0.935, time 134.7 sec
# epoch 115, loss 0.0377, train acc 0.986, test acc 0.934, time 134.9 sec
# epoch 116, loss 0.0426, train acc 0.984, test acc 0.934, time 135.0 sec
# epoch 117, loss 0.0359, train acc 0.987, test acc 0.933, time 134.5 sec
# epoch 118, loss 0.0364, train acc 0.987, test acc 0.931, time 134.7 sec
# epoch 119, loss 0.0367, train acc 0.987, test acc 0.938, time 134.7 sec
# epoch 120, loss 0.0349, train acc 0.987, test acc 0.935, time 134.7 sec
# epoch 121, loss 0.0351, train acc 0.988, test acc 0.936, time 134.5 sec
# epoch 122, loss 0.0348, train acc 0.987, test acc 0.934, time 134.5 sec
# epoch 123, loss 0.0351, train acc 0.987, test acc 0.934, time 134.5 sec
# epoch 124, loss 0.0340, train acc 0.988, test acc 0.935, time 134.6 sec
# epoch 125, loss 0.0334, train acc 0.988, test acc 0.931, time 134.6 sec
# epoch 126, loss 0.0328, train acc 0.988, test acc 0.933, time 134.9 sec
# epoch 127, loss 0.0331, train acc 0.988, test acc 0.930, time 134.8 sec
# epoch 128, loss 0.0318, train acc 0.988, test acc 0.934, time 134.7 sec
# epoch 129, loss 0.0346, train acc 0.988, test acc 0.938, time 134.9 sec
# epoch 130, loss 0.0303, train acc 0.989, test acc 0.933, time 134.8 sec
# epoch 131, loss 0.0309, train acc 0.989, test acc 0.935, time 134.6 sec
# epoch 132, loss 0.0260, train acc 0.991, test acc 0.933, time 134.6 sec
# epoch 133, loss 0.0315, train acc 0.989, test acc 0.938, time 134.8 sec
# epoch 134, loss 0.0255, train acc 0.991, test acc 0.938, time 134.7 sec
# epoch 135, loss 0.0282, train acc 0.989, test acc 0.935, time 134.8 sec
# epoch 136, loss 0.0312, train acc 0.989, test acc 0.940, time 134.8 sec
# epoch 137, loss 0.0243, train acc 0.991, test acc 0.935, time 134.4 sec
# epoch 138, loss 0.0293, train acc 0.990, test acc 0.933, time 134.8 sec
# epoch 139, loss 0.0272, train acc 0.990, test acc 0.934, time 134.8 sec
# epoch 140, loss 0.0269, train acc 0.990, test acc 0.934, time 134.9 sec
# epoch 141, loss 0.0244, train acc 0.991, test acc 0.938, time 134.6 sec
# epoch 142, loss 0.0289, train acc 0.989, test acc 0.934, time 134.6 sec
# epoch 143, loss 0.0253, train acc 0.991, test acc 0.935, time 134.7 sec
# epoch 144, loss 0.0259, train acc 0.991, test acc 0.935, time 134.9 sec
# epoch 145, loss 0.0243, train acc 0.991, test acc 0.933, time 134.8 sec
# epoch 146, loss 0.0185, train acc 0.993, test acc 0.936, time 134.7 sec
# epoch 147, loss 0.0259, train acc 0.991, test acc 0.938, time 134.6 sec
# epoch 148, loss 0.0279, train acc 0.990, test acc 0.934, time 134.8 sec
# epoch 149, loss 0.0218, train acc 0.992, test acc 0.936, time 134.5 sec
# epoch 150, loss 0.0245, train acc 0.991, test acc 0.937, time 134.7 sec
# epoch 151, loss 0.0256, train acc 0.991, test acc 0.930, time 134.5 sec
# epoch 152, loss 0.0221, train acc 0.992, test acc 0.938, time 134.7 sec
# epoch 153, loss 0.0227, train acc 0.992, test acc 0.938, time 134.7 sec
# epoch 154, loss 0.0199, train acc 0.993, test acc 0.938, time 134.8 sec
# epoch 155, loss 0.0208, train acc 0.993, test acc 0.936, time 134.6 sec
# epoch 156, loss 0.0202, train acc 0.993, test acc 0.936, time 134.9 sec
# epoch 157, loss 0.0205, train acc 0.993, test acc 0.939, time 134.9 sec
# epoch 158, loss 0.0203, train acc 0.993, test acc 0.939, time 134.5 sec
# epoch 159, loss 0.0200, train acc 0.993, test acc 0.936, time 134.8 sec
# epoch 160, loss 0.0218, train acc 0.993, test acc 0.933, time 134.7 sec
# epoch 161, loss 0.0185, train acc 0.993, test acc 0.934, time 134.8 sec
# epoch 162, loss 0.0171, train acc 0.994, test acc 0.934, time 134.7 sec
# epoch 163, loss 0.0215, train acc 0.992, test acc 0.935, time 134.6 sec
# epoch 164, loss 0.0193, train acc 0.993, test acc 0.937, time 134.4 sec
# epoch 165, loss 0.0204, train acc 0.993, test acc 0.936, time 134.6 sec
# epoch 166, loss 0.0203, train acc 0.993, test acc 0.936, time 134.6 sec
# epoch 167, loss 0.0144, train acc 0.995, test acc 0.937, time 134.8 sec
# epoch 168, loss 0.0164, train acc 0.994, test acc 0.933, time 134.5 sec
# epoch 169, loss 0.0207, train acc 0.993, test acc 0.935, time 134.7 sec
# epoch 170, loss 0.0170, train acc 0.994, test acc 0.930, time 134.7 sec
# epoch 171, loss 0.0184, train acc 0.994, test acc 0.931, time 134.7 sec
# epoch 172, loss 0.0162, train acc 0.994, test acc 0.936, time 134.6 sec
# epoch 173, loss 0.0185, train acc 0.993, test acc 0.934, time 134.7 sec
# epoch 174, loss 0.0158, train acc 0.994, test acc 0.935, time 134.6 sec
# epoch 175, loss 0.0169, train acc 0.994, test acc 0.939, time 134.7 sec
# epoch 176, loss 0.0146, train acc 0.995, test acc 0.937, time 134.4 sec
# epoch 177, loss 0.0178, train acc 0.994, test acc 0.937, time 134.8 sec
# epoch 178, loss 0.0177, train acc 0.994, test acc 0.934, time 134.9 sec
# epoch 179, loss 0.0173, train acc 0.994, test acc 0.935, time 134.6 sec
# epoch 180, loss 0.0206, train acc 0.993, test acc 0.938, time 134.5 sec
# epoch 181, loss 0.0149, train acc 0.995, test acc 0.939, time 134.8 sec
# epoch 182, loss 0.0138, train acc 0.995, test acc 0.938, time 134.6 sec
# epoch 183, loss 0.0180, train acc 0.994, test acc 0.936, time 134.8 sec
# epoch 184, loss 0.0143, train acc 0.995, test acc 0.936, time 134.7 sec
# epoch 185, loss 0.0162, train acc 0.994, test acc 0.932, time 134.6 sec
# epoch 186, loss 0.0159, train acc 0.994, test acc 0.936, time 134.8 sec
# epoch 187, loss 0.0152, train acc 0.994, test acc 0.934, time 134.6 sec
# epoch 188, loss 0.0149, train acc 0.995, test acc 0.936, time 134.7 sec
# epoch 189, loss 0.0159, train acc 0.994, test acc 0.938, time 134.7 sec
# epoch 190, loss 0.0154, train acc 0.994, test acc 0.935, time 134.9 sec
# epoch 191, loss 0.0146, train acc 0.995, test acc 0.938, time 134.9 sec
# epoch 192, loss 0.0171, train acc 0.994, test acc 0.938, time 134.5 sec
# epoch 193, loss 0.0144, train acc 0.995, test acc 0.935, time 134.6 sec
# epoch 194, loss 0.0146, train acc 0.995, test acc 0.935, time 134.6 sec
# epoch 195, loss 0.0145, train acc 0.995, test acc 0.937, time 134.7 sec
# epoch 196, loss 0.0160, train acc 0.994, test acc 0.936, time 134.6 sec
# epoch 197, loss 0.0136, train acc 0.995, test acc 0.936, time 134.7 sec
# epoch 198, loss 0.0132, train acc 0.996, test acc 0.938, time 134.7 sec
# epoch 199, loss 0.0122, train acc 0.996, test acc 0.932, time 134.9 sec
# epoch 200, loss 0.0124, train acc 0.996, test acc 0.936, time 134.8 sec
